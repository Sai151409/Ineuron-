# %%
import pymongo
import os
import logging
import pandas as pd
import json

# %%
logging.basicConfig(filename = "mongoDB.log", level = logging.INFO, format = "%(asctime)s %(levelname)s %(message)s")

# %%
class mongoDB:
    
    def __init__(self, link, DB_name, DB_collection):
        self.link = pymongo.MongoClient(link)
        self.DB_name = self.link[DB_name]
        self.DB_collection = self.DB_name[DB_collection]
        
    def import_csv(self, file_name, path, sep = None):
        try:
            if ".csv" in file_name:
                df = pd.read_csv(path+"/"+file_name, sep = sep)
                for column in df.columns:
                    if df[column].dtype=='object':
                        df[column] = [float(string.replace(',', '.')) for string in df[column]]
                data = json.loads(df.to_json(orient = "records"))
                self.DB_collection.insert_many(data)
                logging.info("Sucessfully the data is imported in the mongoDB\n")
            else:
                raise Exception("please import the csv file only\n")
        except Exception as e:
            logging.error("The error has occured")
            logging.exception(f"The error is : {e}\n")

    def view_documents(self):
        """It gives the entire collection of documents"""
        try:
            view_list = [i for i in self.DB_collection.find()]
            logging.info(f"Sucessfully print the collection of exist database")
            logging.info("Sucessfully function called \n")
            return view_list
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")

    def insert(self, query, document_count):
        """it inserts the single new document and bulk also"""
        try:
            if document_count == "one" or document_count == "many":
                if document_count == "one":
                    self.DB_collection.insert_one(query)
                    logging.info("Insert the values Sucessfully in the collection\n")
                self.DB_collection.insert_many(query)
                logging.info("Insert the values Sucessfully in the collection\n")
            else:
                raise Exception ("Document count should be one or many\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")
            

    def update(self, document_count,  present_data, update_data):
        """It updates the database with specific condition"""
        try:
            if document_count == "one" or document_count == "many":
                if document_count == "one":
                    self.DB_collection.update_one(present_data, update_data)
                    logging.info("Sucessfully Update the values with a specific condition\n")
                self.DB_collection.update_many(present_data, update_data)
                logging.info("Sucessfully Update the values with a specific condition\n")
            else:
                raise Exception ("Document count should be one or many\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")

    def find(self, document_count = None,  condition = None):
        """Here we find out the documents with different conditions"""
        try:
            view_list = []
            if document_count == "one" or document_count == None:
                if document_count == "one" : 
                    for i in self.DB_collection.find_one(condition):
                        view_list.append(i)
                    logging.info(f"Finding the value with given specific condition {condition}\n")
                    return view_list
                else:
                    for i in self.DB_collection.find(condition):
                        view_list.append(i)
                    logging.info(f"Finding the value with given specific condition {condition}\n")
                    return view_list
            else:
                raise Exception ("Document count should be one or none\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")
    
    def delete(self, document_count, condition = None):
        """it deletes the single document and bulk also"""
        try:
            if document_count == "one" or document_count == "many":
                if document_count == "one":
                    self.DB_collection.delete_one(condition)
                    logging.info("Sucessfully deleted the document from the collection\n")
                self.DB_collection.delete_many(condition)
                logging.info("Sucessfully deleted the documents from the collection\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")
    
    def delete_entire_collection(self):
        """Its deletes the all documents from the colection"""
        try:
            self.DB_collection.delete_many({})
            logging.info("Sucessfully deletes the all documents from the collection\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")
    
    def drop_collection(self, collection_name):
        "Its drop the required collection form the database"
        try:
            self.DB_name.drop_collection(collection_name)
            logging.info("Sucessfully given collection is deleted\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")
            
    def close(self):
        """Its removes the connection between the mongodb and python"""
        try:
            self.link.close()
            logging.info("Sucessfully Its removes the connection between the mongodb and python\n")
        except Exception as e:
            logging.error("The error has ocuured")
            logging.exception(f"The error is : {e}\n")
    
    def __str__(self):
        logging.info("Description of class\n")
        return "It is mongoBD class and performs different nosql operations"

# %%
# Create a connection between the python and mongoDB
password = "test1"
link = f"mongodb+srv://test1:{password}@test1.dv0kt.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"
obj = mongoDB(link, 'mydb', 'coll')

# %%
# Import csv file into monogoDB
path = 'C:/Users/sairamnaaidu/Downloads'
file = "carbon_nanotubes.csv"
obj.import_csv(file, path, sep = ";")

# %%
# View collections in the given data set
obj.view_documents()
# Out:
# [{'_id': ObjectId('621756da4774488f72503c89'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.679005,
#   'Initial atomic coordinate v': 0.701318,
#   'Initial atomic coordinate w': 0.017033,
#   "Calculated atomic coordinates u'": 0.721039,
#   "Calculated atomic coordinates v'": 0.730232,
#   "Calculated atomic coordinates w'": 0.017014},
#  {'_id': ObjectId('621756da4774488f72503c8a'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.717298,
#   'Initial atomic coordinate v': 0.642129,
#   'Initial atomic coordinate w': 0.231319,
#   "Calculated atomic coordinates u'": 0.738414,
#   "Calculated atomic coordinates v'": 0.65675,
#   "Calculated atomic coordinates w'": 0.232369},
#  {'_id': ObjectId('621756da4774488f72503c8b'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.489336,
#   'Initial atomic coordinate v': 0.303751,
#   'Initial atomic coordinate w': 0.088462,
#   "Calculated atomic coordinates u'": 0.477676,
#   "Calculated atomic coordinates v'": 0.263221,
#   "Calculated atomic coordinates w'": 0.088712},
#  {'_id': ObjectId('621756da4774488f72503c8c'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.413957,
#   'Initial atomic coordinate v': 0.632996,
#   'Initial atomic coordinate w': 0.040843,
#   "Calculated atomic coordinates u'": 0.408823,
#   "Calculated atomic coordinates v'": 0.657897,
#   "Calculated atomic coordinates w'": 0.039796},
#  {'_id': ObjectId('621756da4774488f72503c8d'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.334292,
#   'Initial atomic coordinate v': 0.543401,
#   'Initial atomic coordinate w': 0.15989,
#   "Calculated atomic coordinates u'": 0.303349,
#   "Calculated atomic coordinates v'": 0.558807,
#   "Calculated atomic coordinates w'": 0.157373},
#  {'_id': ObjectId('621756da4774488f72503c8e'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.510664,
#   'Initial atomic coordinate v': 0.696249,
#   'Initial atomic coordinate w': 0.255128,
#   "Calculated atomic coordinates u'": 0.496977,
#   "Calculated atomic coordinates v'": 0.725608,
#   "Calculated atomic coordinates w'": 0.25597},
#  {'_id': ObjectId('621756da4774488f72503c8f'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.413957,
#   'Initial atomic coordinate v': 0.632996,
#   'Initial atomic coordinate w': 0.374176,
#   "Calculated atomic coordinates u'": 0.390878,
#   "Calculated atomic coordinates v'": 0.657645,
#   "Calculated atomic coordinates w'": 0.374735},
#  {'_id': ObjectId('621756da4774488f72503c90'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.712552,
#   'Initial atomic coordinate v': 0.55479,
#   'Initial atomic coordinate w': 0.112271,
#   "Calculated atomic coordinates u'": 0.750056,
#   "Calculated atomic coordinates v'": 0.561494,
#   "Calculated atomic coordinates w'": 0.114944},
#  {'_id': ObjectId('621756da4774488f72503c91'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.320995,
#   'Initial atomic coordinate v': 0.298682,
#   'Initial atomic coordinate w': 0.1837,
#   "Calculated atomic coordinates u'": 0.281301,
#   "Calculated atomic coordinates v'": 0.261433,
#   "Calculated atomic coordinates w'": 0.182779},
#  {'_id': ObjectId('621756da4774488f72503c92'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.394742,
#   'Initial atomic coordinate v': 0.279367,
#   'Initial atomic coordinate w': 0.302747,
#   "Calculated atomic coordinates u'": 0.35086,
#   "Calculated atomic coordinates v'": 0.2335,
#   "Calculated atomic coordinates w'": 0.302196},
#  {'_id': ObjectId('621756da4774488f72503c93'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.282702,
#   'Initial atomic coordinate v': 0.357871,
#   'Initial atomic coordinate w': 0.397985,
#   "Calculated atomic coordinates u'": 0.229138,
#   "Calculated atomic coordinates v'": 0.328729,
#   "Calculated atomic coordinates w'": 0.398581},
#  {'_id': ObjectId('621756da4774488f72503c94'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.320995,
#   'Initial atomic coordinate v': 0.298682,
#   'Initial atomic coordinate w': 0.517033,
#   "Calculated atomic coordinates u'": 0.278752,
#   "Calculated atomic coordinates v'": 0.269615,
#   "Calculated atomic coordinates w'": 0.51733},
#  {'_id': ObjectId('621756da4774488f72503c95'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.605258,
#   'Initial atomic coordinate v': 0.720633,
#   'Initial atomic coordinate w': 0.469414,
#   "Calculated atomic coordinates u'": 0.613415,
#   "Calculated atomic coordinates v'": 0.760009,
#   "Calculated atomic coordinates w'": 0.469452},
#  {'_id': ObjectId('621756da4774488f72503c96'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.510664,
#   'Initial atomic coordinate v': 0.696249,
#   'Initial atomic coordinate w': 0.588462,
#   "Calculated atomic coordinates u'": 0.521991,
#   "Calculated atomic coordinates v'": 0.736991,
#   "Calculated atomic coordinates w'": 0.588946},
#  {'_id': ObjectId('621756da4774488f72503c97'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.679005,
#   'Initial atomic coordinate v': 0.701318,
#   'Initial atomic coordinate w': 0.6837,
#   "Calculated atomic coordinates u'": 0.718811,
#   "Calculated atomic coordinates v'": 0.738577,
#   "Calculated atomic coordinates w'": 0.68244},
#  {'_id': ObjectId('621756da4774488f72503c98'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.605258,
#   'Initial atomic coordinate v': 0.720633,
#   'Initial atomic coordinate w': 0.802747,
#   "Calculated atomic coordinates u'": 0.649178,
#   "Calculated atomic coordinates v'": 0.766301,
#   "Calculated atomic coordinates w'": 0.80193},
#  {'_id': ObjectId('621756da4774488f72503c99'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.665708,
#   'Initial atomic coordinate v': 0.456599,
#   'Initial atomic coordinate w': 0.326557,
#   "Calculated atomic coordinates u'": 0.680389,
#   "Calculated atomic coordinates v'": 0.444562,
#   "Calculated atomic coordinates w'": 0.327502},
#  {'_id': ObjectId('621756da4774488f72503c9a'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.712552,
#   'Initial atomic coordinate v': 0.55479,
#   'Initial atomic coordinate w': 0.445605,
#   "Calculated atomic coordinates u'": 0.737216,
#   "Calculated atomic coordinates v'": 0.552056,
#   "Calculated atomic coordinates w'": 0.443517},
#  {'_id': ObjectId('621756da4774488f72503c9b'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.586043,
#   'Initial atomic coordinate v': 0.367004,
#   'Initial atomic coordinate w': 0.540843,
#   "Calculated atomic coordinates u'": 0.591153,
#   "Calculated atomic coordinates v'": 0.342069,
#   "Calculated atomic coordinates w'": 0.540172},
#  {'_id': ObjectId('621756da4774488f72503c9c'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.665708,
#   'Initial atomic coordinate v': 0.456599,
#   'Initial atomic coordinate w': 0.65989,
#   "Calculated atomic coordinates u'": 0.697242,
#   "Calculated atomic coordinates v'": 0.441516,
#   "Calculated atomic coordinates w'": 0.657521},
#  {'_id': ObjectId('621756da4774488f72503c9d'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.287448,
#   'Initial atomic coordinate v': 0.44521,
#   'Initial atomic coordinate w': 0.612271,
#   "Calculated atomic coordinates u'": 0.249571,
#   "Calculated atomic coordinates v'": 0.438057,
#   "Calculated atomic coordinates w'": 0.614939},
#  {'_id': ObjectId('621756da4774488f72503c9e'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.282702,
#   'Initial atomic coordinate v': 0.357871,
#   'Initial atomic coordinate w': 0.731319,
#   "Calculated atomic coordinates u'": 0.262916,
#   "Calculated atomic coordinates v'": 0.343512,
#   "Calculated atomic coordinates w'": 0.732213},
#  {'_id': ObjectId('621756da4774488f72503c9f'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.334292,
#   'Initial atomic coordinate v': 0.543401,
#   'Initial atomic coordinate w': 0.826557,
#   "Calculated atomic coordinates u'": 0.320053,
#   "Calculated atomic coordinates v'": 0.555754,
#   "Calculated atomic coordinates w'": 0.827503},
#  {'_id': ObjectId('621756da4774488f72503ca0'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.287448,
#   'Initial atomic coordinate v': 0.44521,
#   'Initial atomic coordinate w': 0.945605,
#   "Calculated atomic coordinates u'": 0.262054,
#   "Calculated atomic coordinates v'": 0.44817,
#   "Calculated atomic coordinates w'": 0.943402},
#  {'_id': ObjectId('621756da4774488f72503ca1'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.717298,
#   'Initial atomic coordinate v': 0.642129,
#   'Initial atomic coordinate w': 0.897985,
#   "Calculated atomic coordinates u'": 0.770521,
#   "Calculated atomic coordinates v'": 0.670869,
#   "Calculated atomic coordinates w'": 0.898389},
#  {'_id': ObjectId('621756da4774488f72503ca2'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.489336,
#   'Initial atomic coordinate v': 0.303751,
#   'Initial atomic coordinate w': 0.755128,
#   "Calculated atomic coordinates u'": 0.50356,
#   "Calculated atomic coordinates v'": 0.27443,
#   "Calculated atomic coordinates w'": 0.75629},
#  {'_id': ObjectId('621756da4774488f72503ca3'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.586043,
#   'Initial atomic coordinate v': 0.367004,
#   'Initial atomic coordinate w': 0.874176,
#   "Calculated atomic coordinates u'": 0.609,
#   "Calculated atomic coordinates v'": 0.342123,
#   "Calculated atomic coordinates w'": 0.875088},
#  {'_id': ObjectId('621756da4774488f72503ca4'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.394742,
#   'Initial atomic coordinate v': 0.279367,
#   'Initial atomic coordinate w': 0.969414,
#   "Calculated atomic coordinates u'": 0.385666,
#   "Calculated atomic coordinates v'": 0.240071,
#   "Calculated atomic coordinates w'": 0.969157},
#  {'_id': ObjectId('621756da4774488f72503ca5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.591598,
#   'Initial atomic coordinate v': 0.760361,
#   'Initial atomic coordinate w': 0.05909,
#   "Calculated atomic coordinates u'": 0.59912,
#   "Calculated atomic coordinates v'": 0.779052,
#   "Calculated atomic coordinates w'": 0.058651},
#  {'_id': ObjectId('621756da4774488f72503ca6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.24301,
#   'Initial atomic coordinate v': 0.424391,
#   'Initial atomic coordinate w': 0.020628,
#   "Calculated atomic coordinates u'": 0.222068,
#   "Calculated atomic coordinates v'": 0.414703,
#   "Calculated atomic coordinates w'": 0.020882},
#  {'_id': ObjectId('621756da4774488f72503ca7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.348135,
#   'Initial atomic coordinate v': 0.611237,
#   'Initial atomic coordinate w': 0.084731,
#   "Calculated atomic coordinates u'": 0.337437,
#   "Calculated atomic coordinates v'": 0.618899,
#   "Calculated atomic coordinates w'": 0.085676},
#  {'_id': ObjectId('621756da4774488f72503ca8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.300826,
#   'Initial atomic coordinate v': 0.550669,
#   'Initial atomic coordinate w': 0.174474,
#   "Calculated atomic coordinates u'": 0.287789,
#   "Calculated atomic coordinates v'": 0.556575,
#   "Calculated atomic coordinates w'": 0.174486},
#  {'_id': ObjectId('621756da4774488f72503ca9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.732854,
#   'Initial atomic coordinate v': 0.724426,
#   'Initial atomic coordinate w': 0.123192,
#   "Calculated atomic coordinates u'": 0.754953,
#   "Calculated atomic coordinates v'": 0.742501,
#   "Calculated atomic coordinates w'": 0.123074},
#  {'_id': ObjectId('621756da4774488f72503caa'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.696244,
#   'Initial atomic coordinate v': 0.751243,
#   'Initial atomic coordinate w': 0.212936,
#   "Calculated atomic coordinates u'": 0.716721,
#   "Calculated atomic coordinates v'": 0.774579,
#   "Calculated atomic coordinates w'": 0.211887},
#  {'_id': ObjectId('621756da4774488f72503cab'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.764136,
#   'Initial atomic coordinate v': 0.633981,
#   'Initial atomic coordinate w': 0.277038,
#   "Calculated atomic coordinates u'": 0.787393,
#   "Calculated atomic coordinates v'": 0.647285,
#   "Calculated atomic coordinates w'": 0.277407},
#  {'_id': ObjectId('621756da4774488f72503cac'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.755932,
#   'Initial atomic coordinate v': 0.684567,
#   'Initial atomic coordinate w': 0.366782,
#   "Calculated atomic coordinates u'": 0.775712,
#   "Calculated atomic coordinates v'": 0.700545,
#   "Calculated atomic coordinates w'": 0.366505},
#  {'_id': ObjectId('621756da4774488f72503cad'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.699174,
#   'Initial atomic coordinate v': 0.449331,
#   'Initial atomic coordinate w': 0.007807,
#   "Calculated atomic coordinates u'": 0.72086,
#   "Calculated atomic coordinates v'": 0.444281,
#   "Calculated atomic coordinates w'": 0.00759},
#  {'_id': ObjectId('621756da4774488f72503cae'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.734908,
#   'Initial atomic coordinate v': 0.512843,
#   'Initial atomic coordinate w': 0.097551,
#   "Calculated atomic coordinates u'": 0.762097,
#   "Calculated atomic coordinates v'": 0.516121,
#   "Calculated atomic coordinates w'": 0.096337},
#  {'_id': ObjectId('621756da4774488f72503caf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.303756,
#   'Initial atomic coordinate v': 0.248757,
#   'Initial atomic coordinate w': 0.046269,
#   "Calculated atomic coordinates u'": 0.293584,
#   "Calculated atomic coordinates v'": 0.229065,
#   "Calculated atomic coordinates w'": 0.047346},
#  {'_id': ObjectId('621756da4774488f72503cb0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.351772,
#   'Initial atomic coordinate v': 0.236542,
#   'Initial atomic coordinate w': 0.136013,
#   "Calculated atomic coordinates u'": 0.349972,
#   "Calculated atomic coordinates v'": 0.22059,
#   "Calculated atomic coordinates w'": 0.136027},
#  {'_id': ObjectId('621756da4774488f72503cb1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.244068,
#   'Initial atomic coordinate v': 0.315433,
#   'Initial atomic coordinate w': 0.200115,
#   "Calculated atomic coordinates u'": 0.232016,
#   "Calculated atomic coordinates v'": 0.304156,
#   "Calculated atomic coordinates w'": 0.201163},
#  {'_id': ObjectId('621756da4774488f72503cb2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.267146,
#   'Initial atomic coordinate v': 0.275574,
#   'Initial atomic coordinate w': 0.289859,
#   "Calculated atomic coordinates u'": 0.259193,
#   "Calculated atomic coordinates v'": 0.263096,
#   "Calculated atomic coordinates w'": 0.289735},
#  {'_id': ObjectId('621756da4774488f72503cb3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.465969,
#   'Initial atomic coordinate v': 0.709835,
#   'Initial atomic coordinate w': 0.238577,
#   "Calculated atomic coordinates u'": 0.467543,
#   "Calculated atomic coordinates v'": 0.732466,
#   "Calculated atomic coordinates w'": 0.238691},
#  {'_id': ObjectId('621756da4774488f72503cb4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.40427,
#   'Initial atomic coordinate v': 0.665341,
#   'Initial atomic coordinate w': 0.32832,
#   "Calculated atomic coordinates u'": 0.398427,
#   "Calculated atomic coordinates v'": 0.685067,
#   "Calculated atomic coordinates w'": 0.327159},
#  {'_id': ObjectId('621756da4774488f72503cb5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.591598,
#   'Initial atomic coordinate v': 0.760361,
#   'Initial atomic coordinate w': 0.392423,
#   "Calculated atomic coordinates u'": 0.599318,
#   "Calculated atomic coordinates v'": 0.782562,
#   "Calculated atomic coordinates w'": 0.392936},
#  {'_id': ObjectId('621756da4774488f72503cb6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.529645,
#   'Initial atomic coordinate v': 0.742134,
#   'Initial atomic coordinate w': 0.482166,
#   "Calculated atomic coordinates u'": 0.529179,
#   "Calculated atomic coordinates v'": 0.763965,
#   "Calculated atomic coordinates w'": 0.48165},
#  {'_id': ObjectId('621756da4774488f72503cb7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.59573,
#   'Initial atomic coordinate v': 0.334659,
#   'Initial atomic coordinate w': 0.161654,
#   "Calculated atomic coordinates u'": 0.613188,
#   "Calculated atomic coordinates v'": 0.322504,
#   "Calculated atomic coordinates w'": 0.16211},
#  {'_id': ObjectId('621756da4774488f72503cb8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.651865,
#   'Initial atomic coordinate v': 0.388763,
#   'Initial atomic coordinate w': 0.251397,
#   "Calculated atomic coordinates u'": 0.674862,
#   "Calculated atomic coordinates v'": 0.383646,
#   "Calculated atomic coordinates w'": 0.250882},
#  {'_id': ObjectId('621756da4774488f72503cb9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.470355,
#   'Initial atomic coordinate v': 0.257866,
#   'Initial atomic coordinate w': 0.3155,
#   "Calculated atomic coordinates u'": 0.476696,
#   "Calculated atomic coordinates v'": 0.239962,
#   "Calculated atomic coordinates w'": 0.316373},
#  {'_id': ObjectId('621756da4774488f72503cba'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.534031,
#   'Initial atomic coordinate v': 0.290165,
#   'Initial atomic coordinate w': 0.405243,
#   "Calculated atomic coordinates u'": 0.543931,
#   "Calculated atomic coordinates v'": 0.27459,
#   "Calculated atomic coordinates w'": 0.405442},
#  {'_id': ObjectId('621756da4774488f72503cbb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.24301,
#   'Initial atomic coordinate v': 0.424391,
#   'Initial atomic coordinate w': 0.353961,
#   "Calculated atomic coordinates u'": 0.22811,
#   "Calculated atomic coordinates v'": 0.42237,
#   "Calculated atomic coordinates w'": 0.353687},
#  {'_id': ObjectId('621756da4774488f72503cbc'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.235864,
#   'Initial atomic coordinate v': 0.366019,
#   'Initial atomic coordinate w': 0.443705,
#   "Calculated atomic coordinates u'": 0.21931,
#   "Calculated atomic coordinates v'": 0.358527,
#   "Calculated atomic coordinates w'": 0.442351},
#  {'_id': ObjectId('621756da4774488f72503cbd'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.300826,
#   'Initial atomic coordinate v': 0.550669,
#   'Initial atomic coordinate w': 0.507807,
#   "Calculated atomic coordinates u'": 0.27914,
#   "Calculated atomic coordinates v'": 0.555719,
#   "Calculated atomic coordinates w'": 0.50759},
#  {'_id': ObjectId('621756da4774488f72503cbe'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.265092,
#   'Initial atomic coordinate v': 0.487157,
#   'Initial atomic coordinate w': 0.597551,
#   "Calculated atomic coordinates u'": 0.237903,
#   "Calculated atomic coordinates v'": 0.483879,
#   "Calculated atomic coordinates w'": 0.596337},
#  {'_id': ObjectId('621756da4774488f72503cbf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.696244,
#   'Initial atomic coordinate v': 0.751243,
#   'Initial atomic coordinate w': 0.546269,
#   "Calculated atomic coordinates u'": 0.706416,
#   "Calculated atomic coordinates v'": 0.770935,
#   "Calculated atomic coordinates w'": 0.547346},
#  {'_id': ObjectId('621756da4774488f72503cc0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.648228,
#   'Initial atomic coordinate v': 0.763458,
#   'Initial atomic coordinate w': 0.636013,
#   "Calculated atomic coordinates u'": 0.650028,
#   "Calculated atomic coordinates v'": 0.77941,
#   "Calculated atomic coordinates w'": 0.636027},
#  {'_id': ObjectId('621756da4774488f72503cc1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.755932,
#   'Initial atomic coordinate v': 0.684567,
#   'Initial atomic coordinate w': 0.700115,
#   "Calculated atomic coordinates u'": 0.767984,
#   "Calculated atomic coordinates v'": 0.695844,
#   "Calculated atomic coordinates w'": 0.701163},
#  {'_id': ObjectId('621756da4774488f72503cc2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.732854,
#   'Initial atomic coordinate v': 0.724426,
#   'Initial atomic coordinate w': 0.789859,
#   "Calculated atomic coordinates u'": 0.740808,
#   "Calculated atomic coordinates v'": 0.736904,
#   "Calculated atomic coordinates w'": 0.789735},
#  {'_id': ObjectId('621756da4774488f72503cc3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.734908,
#   'Initial atomic coordinate v': 0.512843,
#   'Initial atomic coordinate w': 0.430884,
#   "Calculated atomic coordinates u'": 0.76046,
#   "Calculated atomic coordinates v'": 0.51884,
#   "Calculated atomic coordinates w'": 0.432119},
#  {'_id': ObjectId('621756da4774488f72503cc4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.75699,
#   'Initial atomic coordinate v': 0.575609,
#   'Initial atomic coordinate w': 0.520628,
#   "Calculated atomic coordinates u'": 0.777932,
#   "Calculated atomic coordinates v'": 0.585297,
#   "Calculated atomic coordinates w'": 0.520882},
#  {'_id': ObjectId('621756da4774488f72503cc5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.351772,
#   'Initial atomic coordinate v': 0.236542,
#   'Initial atomic coordinate w': 0.469346,
#   "Calculated atomic coordinates u'": 0.345355,
#   "Calculated atomic coordinates v'": 0.221578,
#   "Calculated atomic coordinates w'": 0.469496},
#  {'_id': ObjectId('621756da4774488f72503cc6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.408402,
#   'Initial atomic coordinate v': 0.239639,
#   'Initial atomic coordinate w': 0.55909,
#   "Calculated atomic coordinates u'": 0.40088,
#   "Calculated atomic coordinates v'": 0.220949,
#   "Calculated atomic coordinates w'": 0.558651},
#  {'_id': ObjectId('621756da4774488f72503cc7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.267146,
#   'Initial atomic coordinate v': 0.275574,
#   'Initial atomic coordinate w': 0.623192,
#   "Calculated atomic coordinates u'": 0.245047,
#   "Calculated atomic coordinates v'": 0.257499,
#   "Calculated atomic coordinates w'": 0.623074},
#  {'_id': ObjectId('621756da4774488f72503cc8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.303756,
#   'Initial atomic coordinate v': 0.248757,
#   'Initial atomic coordinate w': 0.712936,
#   "Calculated atomic coordinates u'": 0.283279,
#   "Calculated atomic coordinates v'": 0.225421,
#   "Calculated atomic coordinates w'": 0.711887},
#  {'_id': ObjectId('621756da4774488f72503cc9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.40427,
#   'Initial atomic coordinate v': 0.665341,
#   'Initial atomic coordinate w': 0.661654,
#   "Calculated atomic coordinates u'": 0.386812,
#   "Calculated atomic coordinates v'": 0.677496,
#   "Calculated atomic coordinates w'": 0.66211},
#  {'_id': ObjectId('621756da4774488f72503cca'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.348135,
#   'Initial atomic coordinate v': 0.611237,
#   'Initial atomic coordinate w': 0.751397,
#   "Calculated atomic coordinates u'": 0.325138,
#   "Calculated atomic coordinates v'": 0.616354,
#   "Calculated atomic coordinates w'": 0.750882},
#  {'_id': ObjectId('621756da4774488f72503ccb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.529645,
#   'Initial atomic coordinate v': 0.742134,
#   'Initial atomic coordinate w': 0.8155,
#   "Calculated atomic coordinates u'": 0.523304,
#   "Calculated atomic coordinates v'": 0.760038,
#   "Calculated atomic coordinates w'": 0.816373},
#  {'_id': ObjectId('621756da4774488f72503ccc'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.465969,
#   'Initial atomic coordinate v': 0.709835,
#   'Initial atomic coordinate w': 0.905243,
#   "Calculated atomic coordinates u'": 0.456069,
#   "Calculated atomic coordinates v'": 0.72541,
#   "Calculated atomic coordinates w'": 0.905442},
#  {'_id': ObjectId('621756da4774488f72503ccd'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.764136,
#   'Initial atomic coordinate v': 0.633981,
#   'Initial atomic coordinate w': 0.943705,
#   "Calculated atomic coordinates u'": 0.78069,
#   "Calculated atomic coordinates v'": 0.641473,
#   "Calculated atomic coordinates w'": 0.942351},
#  {'_id': ObjectId('621756da4774488f72503cce'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.651865,
#   'Initial atomic coordinate v': 0.388763,
#   'Initial atomic coordinate w': 0.584731,
#   "Calculated atomic coordinates u'": 0.662563,
#   "Calculated atomic coordinates v'": 0.381101,
#   "Calculated atomic coordinates w'": 0.585676},
#  {'_id': ObjectId('621756da4774488f72503ccf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.699174,
#   'Initial atomic coordinate v': 0.449331,
#   'Initial atomic coordinate w': 0.674474,
#   "Calculated atomic coordinates u'": 0.712211,
#   "Calculated atomic coordinates v'": 0.443425,
#   "Calculated atomic coordinates w'": 0.674486},
#  {'_id': ObjectId('621756da4774488f72503cd0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.534031,
#   'Initial atomic coordinate v': 0.290165,
#   'Initial atomic coordinate w': 0.738577,
#   "Calculated atomic coordinates u'": 0.532457,
#   "Calculated atomic coordinates v'": 0.267534,
#   "Calculated atomic coordinates w'": 0.738691},
#  {'_id': ObjectId('621756da4774488f72503cd1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.59573,
#   'Initial atomic coordinate v': 0.334659,
#   'Initial atomic coordinate w': 0.82832,
#   "Calculated atomic coordinates u'": 0.601573,
#   "Calculated atomic coordinates v'": 0.314933,
#   "Calculated atomic coordinates w'": 0.827159},
#  {'_id': ObjectId('621756da4774488f72503cd2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.235864,
#   'Initial atomic coordinate v': 0.366019,
#   'Initial atomic coordinate w': 0.777038,
#   "Calculated atomic coordinates u'": 0.212606,
#   "Calculated atomic coordinates v'": 0.352715,
#   "Calculated atomic coordinates w'": 0.777407},
#  {'_id': ObjectId('621756da4774488f72503cd3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.244068,
#   'Initial atomic coordinate v': 0.315433,
#   'Initial atomic coordinate w': 0.866782,
#   "Calculated atomic coordinates u'": 0.224287,
#   "Calculated atomic coordinates v'": 0.299455,
#   "Calculated atomic coordinates w'": 0.866505},
#  {'_id': ObjectId('621756da4774488f72503cd4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.265092,
#   'Initial atomic coordinate v': 0.487157,
#   'Initial atomic coordinate w': 0.930884,
#   "Calculated atomic coordinates u'": 0.23954,
#   "Calculated atomic coordinates v'": 0.48116,
#   "Calculated atomic coordinates w'": 0.932119},
#  {'_id': ObjectId('621756da4774488f72503cd5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.648228,
#   'Initial atomic coordinate v': 0.763458,
#   'Initial atomic coordinate w': 0.969346,
#   "Calculated atomic coordinates u'": 0.654645,
#   "Calculated atomic coordinates v'": 0.778422,
#   "Calculated atomic coordinates w'": 0.969496},
#  {'_id': ObjectId('621756da4774488f72503cd6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.75699,
#   'Initial atomic coordinate v': 0.575609,
#   'Initial atomic coordinate w': 0.853961,
#   "Calculated atomic coordinates u'": 0.77189,
#   "Calculated atomic coordinates v'": 0.57763,
#   "Calculated atomic coordinates w'": 0.853688},
#  {'_id': ObjectId('621756da4774488f72503cd7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.408402,
#   'Initial atomic coordinate v': 0.239639,
#   'Initial atomic coordinate w': 0.892423,
#   "Calculated atomic coordinates u'": 0.400682,
#   "Calculated atomic coordinates v'": 0.217438,
#   "Calculated atomic coordinates w'": 0.892936},
#  {'_id': ObjectId('621756da4774488f72503cd8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.470355,
#   'Initial atomic coordinate v': 0.257866,
#   'Initial atomic coordinate w': 0.982166,
#   "Calculated atomic coordinates u'": 0.470821,
#   "Calculated atomic coordinates v'": 0.236035,
#   "Calculated atomic coordinates w'": 0.98165},
#  {'_id': ObjectId('621756da4774488f72503cd9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.637257,
#   'Initial atomic coordinate v': 0.791312,
#   'Initial atomic coordinate w': 0.032917,
#   "Calculated atomic coordinates u'": 0.636717,
#   "Calculated atomic coordinates v'": 0.803969,
#   "Calculated atomic coordinates w'": 0.032929},
#  {'_id': ObjectId('621756da4774488f72503cda'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.403783,
#   'Initial atomic coordinate v': 0.690165,
#   'Initial atomic coordinate w': 0.041689,
#   "Calculated atomic coordinates u'": 0.393472,
#   "Calculated atomic coordinates v'": 0.694676,
#   "Calculated atomic coordinates w'": 0.041784},
#  {'_id': ObjectId('621756da4774488f72503cdb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.31966,
#   'Initial atomic coordinate v': 0.608137,
#   'Initial atomic coordinate w': 0.111865,
#   "Calculated atomic coordinates u'": 0.30593,
#   "Calculated atomic coordinates v'": 0.607015,
#   "Calculated atomic coordinates w'": 0.112105},
#  {'_id': ObjectId('621756da4774488f72503cdc'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.743096,
#   'Initial atomic coordinate v': 0.760817,
#   'Initial atomic coordinate w': 0.094321,
#   "Calculated atomic coordinates u'": 0.753137,
#   "Calculated atomic coordinates v'": 0.775437,
#   "Calculated atomic coordinates w'": 0.094168},
#  {'_id': ObjectId('621756da4774488f72503cdd'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.677708,
#   'Initial atomic coordinate v': 0.788935,
#   'Initial atomic coordinate w': 0.164496,
#   "Calculated atomic coordinates u'": 0.682379,
#   "Calculated atomic coordinates v'": 0.804355,
#   "Calculated atomic coordinates w'": 0.164358},
#  {'_id': ObjectId('621756da4774488f72503cde'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.766249,
#   'Initial atomic coordinate v': 0.735843,
#   'Initial atomic coordinate w': 0.2259,
#   "Calculated atomic coordinates u'": 0.777945,
#   "Calculated atomic coordinates v'": 0.749432,
#   "Calculated atomic coordinates w'": 0.225798},
#  {'_id': ObjectId('621756da4774488f72503cdf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.713311,
#   'Initial atomic coordinate v': 0.778677,
#   'Initial atomic coordinate w': 0.296075,
#   "Calculated atomic coordinates u'": 0.720745,
#   "Calculated atomic coordinates v'": 0.794402,
#   "Calculated atomic coordinates w'": 0.296029},
#  {'_id': ObjectId('621756da4774488f72503ce0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.549619,
#   'Initial atomic coordinate v': 0.276071,
#   'Initial atomic coordinate w': 0.006602,
#   "Calculated atomic coordinates u'": 0.555071,
#   "Calculated atomic coordinates v'": 0.269279,
#   "Calculated atomic coordinates w'": 0.006501},
#  {'_id': ObjectId('621756da4774488f72503ce1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.233751,
#   'Initial atomic coordinate v': 0.264157,
#   'Initial atomic coordinate w': 0.059233,
#   "Calculated atomic coordinates u'": 0.219019,
#   "Calculated atomic coordinates v'": 0.246063,
#   "Calculated atomic coordinates w'": 0.059347},
#  {'_id': ObjectId('621756da4774488f72503ce2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.209389,
#   'Initial atomic coordinate v': 0.3741,
#   'Initial atomic coordinate w': 0.120637,
#   "Calculated atomic coordinates u'": 0.19467,
#   "Calculated atomic coordinates v'": 0.363701,
#   "Calculated atomic coordinates w'": 0.120952},
#  {'_id': ObjectId('621756da4774488f72503ce3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.21786,
#   'Initial atomic coordinate v': 0.295564,
#   'Initial atomic coordinate w': 0.190812,
#   "Calculated atomic coordinates u'": 0.205895,
#   "Calculated atomic coordinates v'": 0.280628,
#   "Calculated atomic coordinates w'": 0.191151},
#  {'_id': ObjectId('621756da4774488f72503ce4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.450381,
#   'Initial atomic coordinate v': 0.723929,
#   'Initial atomic coordinate w': 0.173268,
#   "Calculated atomic coordinates u'": 0.445071,
#   "Calculated atomic coordinates v'": 0.732091,
#   "Calculated atomic coordinates w'": 0.173231},
#  {'_id': ObjectId('621756da4774488f72503ce5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.359809,
#   'Initial atomic coordinate v': 0.651213,
#   'Initial atomic coordinate w': 0.243444,
#   "Calculated atomic coordinates u'": 0.348764,
#   "Calculated atomic coordinates v'": 0.654129,
#   "Calculated atomic coordinates w'": 0.243503},
#  {'_id': ObjectId('621756da4774488f72503ce6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.498332,
#   'Initial atomic coordinate v': 0.751585,
#   'Initial atomic coordinate w': 0.304847,
#   "Calculated atomic coordinates u'": 0.495486,
#   "Calculated atomic coordinates v'": 0.763508,
#   "Calculated atomic coordinates w'": 0.304887},
#  {'_id': ObjectId('621756da4774488f72503ce7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.403783,
#   'Initial atomic coordinate v': 0.690165,
#   'Initial atomic coordinate w': 0.375023,
#   "Calculated atomic coordinates u'": 0.39409,
#   "Calculated atomic coordinates v'": 0.694968,
#   "Calculated atomic coordinates w'": 0.375015},
#  {'_id': ObjectId('621756da4774488f72503ce8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.78214,
#   'Initial atomic coordinate v': 0.704436,
#   'Initial atomic coordinate w': 0.357479,
#   "Calculated atomic coordinates u'": 0.797217,
#   "Calculated atomic coordinates v'": 0.718068,
#   "Calculated atomic coordinates w'": 0.357196},
#  {'_id': ObjectId('621756da4774488f72503ce9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.743096,
#   'Initial atomic coordinate v': 0.760817,
#   'Initial atomic coordinate w': 0.427654,
#   "Calculated atomic coordinates u'": 0.754694,
#   "Calculated atomic coordinates v'": 0.777448,
#   "Calculated atomic coordinates w'": 0.427477},
#  {'_id': ObjectId('621756da4774488f72503cea'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.790335,
#   'Initial atomic coordinate v': 0.667452,
#   'Initial atomic coordinate w': 0.489058,
#   "Calculated atomic coordinates u'": 0.807952,
#   "Calculated atomic coordinates v'": 0.681054,
#   "Calculated atomic coordinates w'": 0.489132},
#  {'_id': ObjectId('621756da4774488f72503ceb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.766249,
#   'Initial atomic coordinate v': 0.735843,
#   'Initial atomic coordinate w': 0.559233,
#   "Calculated atomic coordinates u'": 0.780981,
#   "Calculated atomic coordinates v'": 0.753937,
#   "Calculated atomic coordinates w'": 0.559347},
#  {'_id': ObjectId('621756da4774488f72503cec'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.74492,
#   'Initial atomic coordinate v': 0.485609,
#   'Initial atomic coordinate w': 0.015373,
#   "Calculated atomic coordinates u'": 0.75736,
#   "Calculated atomic coordinates v'": 0.487774,
#   "Calculated atomic coordinates w'": 0.015348},
#  {'_id': ObjectId('621756da4774488f72503ced'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.782959,
#   'Initial atomic coordinate v': 0.580915,
#   'Initial atomic coordinate w': 0.085549,
#   "Calculated atomic coordinates u'": 0.795642,
#   "Calculated atomic coordinates v'": 0.588879,
#   "Calculated atomic coordinates w'": 0.085488},
#  {'_id': ObjectId('621756da4774488f72503cee'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.406938,
#   'Initial atomic coordinate v': 0.214257,
#   'Initial atomic coordinate w': 0.068005,
#   "Calculated atomic coordinates u'": 0.402862,
#   "Calculated atomic coordinates v'": 0.199315,
#   "Calculated atomic coordinates w'": 0.067847},
#  {'_id': ObjectId('621756da4774488f72503cef'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.501668,
#   'Initial atomic coordinate v': 0.248415,
#   'Initial atomic coordinate w': 0.138181,
#   "Calculated atomic coordinates u'": 0.505401,
#   "Calculated atomic coordinates v'": 0.236223,
#   "Calculated atomic coordinates w'": 0.137935},
#  {'_id': ObjectId('621756da4774488f72503cf0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.362743,
#   'Initial atomic coordinate v': 0.208688,
#   'Initial atomic coordinate w': 0.199584,
#   "Calculated atomic coordinates u'": 0.358686,
#   "Calculated atomic coordinates v'": 0.192911,
#   "Calculated atomic coordinates w'": 0.199771},
#  {'_id': ObjectId('621756da4774488f72503cf1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.453671,
#   'Initial atomic coordinate v': 0.227621,
#   'Initial atomic coordinate w': 0.269759,
#   "Calculated atomic coordinates u'": 0.458173,
#   "Calculated atomic coordinates v'": 0.215511,
#   "Calculated atomic coordinates w'": 0.269828},
#  {'_id': ObjectId('621756da4774488f72503cf2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.217041,
#   'Initial atomic coordinate v': 0.419085,
#   'Initial atomic coordinate w': 0.252216,
#   "Calculated atomic coordinates u'": 0.204773,
#   "Calculated atomic coordinates v'": 0.412301,
#   "Calculated atomic coordinates w'": 0.252384},
#  {'_id': ObjectId('621756da4774488f72503cf3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.209665,
#   'Initial atomic coordinate v': 0.332548,
#   'Initial atomic coordinate w': 0.322391,
#   "Calculated atomic coordinates u'": 0.198094,
#   "Calculated atomic coordinates v'": 0.319888,
#   "Calculated atomic coordinates w'": 0.322493},
#  {'_id': ObjectId('621756da4774488f72503cf4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.232411,
#   'Initial atomic coordinate v': 0.466278,
#   'Initial atomic coordinate w': 0.383795,
#   "Calculated atomic coordinates u'": 0.219043,
#   "Calculated atomic coordinates v'": 0.460817,
#   "Calculated atomic coordinates w'": 0.383849},
#  {'_id': ObjectId('621756da4774488f72503cf5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.209389,
#   'Initial atomic coordinate v': 0.3741,
#   'Initial atomic coordinate w': 0.45397,
#   "Calculated atomic coordinates u'": 0.196708,
#   "Calculated atomic coordinates v'": 0.362862,
#   "Calculated atomic coordinates w'": 0.454006},
#  {'_id': ObjectId('621756da4774488f72503cf6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.546329,
#   'Initial atomic coordinate v': 0.772379,
#   'Initial atomic coordinate w': 0.436426,
#   "Calculated atomic coordinates u'": 0.546758,
#   "Calculated atomic coordinates v'": 0.784127,
#   "Calculated atomic coordinates w'": 0.436204},
#  {'_id': ObjectId('621756da4774488f72503cf7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.450381,
#   'Initial atomic coordinate v': 0.723929,
#   'Initial atomic coordinate w': 0.506602,
#   "Calculated atomic coordinates u'": 0.444929,
#   "Calculated atomic coordinates v'": 0.730721,
#   "Calculated atomic coordinates w'": 0.506501},
#  {'_id': ObjectId('621756da4774488f72503cf8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.593062,
#   'Initial atomic coordinate v': 0.785743,
#   'Initial atomic coordinate w': 0.568005,
#   "Calculated atomic coordinates u'": 0.597138,
#   "Calculated atomic coordinates v'": 0.800685,
#   "Calculated atomic coordinates w'": 0.567847},
#  {'_id': ObjectId('621756da4774488f72503cf9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.498332,
#   'Initial atomic coordinate v': 0.751585,
#   'Initial atomic coordinate w': 0.638181,
#   "Calculated atomic coordinates u'": 0.494599,
#   "Calculated atomic coordinates v'": 0.763777,
#   "Calculated atomic coordinates w'": 0.637935},
#  {'_id': ObjectId('621756da4774488f72503cfa'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.78214,
#   'Initial atomic coordinate v': 0.704436,
#   'Initial atomic coordinate w': 0.690812,
#   "Calculated atomic coordinates u'": 0.794105,
#   "Calculated atomic coordinates v'": 0.719372,
#   "Calculated atomic coordinates w'": 0.691151},
#  {'_id': ObjectId('621756da4774488f72503cfb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.790335,
#   'Initial atomic coordinate v': 0.667452,
#   'Initial atomic coordinate w': 0.822391,
#   "Calculated atomic coordinates u'": 0.801906,
#   "Calculated atomic coordinates v'": 0.680112,
#   "Calculated atomic coordinates w'": 0.822493},
#  {'_id': ObjectId('621756da4774488f72503cfc'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.71557,
#   'Initial atomic coordinate v': 0.437889,
#   'Initial atomic coordinate w': 0.146952,
#   "Calculated atomic coordinates u'": 0.72519,
#   "Calculated atomic coordinates v'": 0.436767,
#   "Calculated atomic coordinates w'": 0.146746},
#  {'_id': ObjectId('621756da4774488f72503cfd'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.767589,
#   'Initial atomic coordinate v': 0.533722,
#   'Initial atomic coordinate w': 0.217128,
#   "Calculated atomic coordinates u'": 0.781561,
#   "Calculated atomic coordinates v'": 0.539864,
#   "Calculated atomic coordinates w'": 0.216971},
#  {'_id': ObjectId('621756da4774488f72503cfe'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.68034,
#   'Initial atomic coordinate v': 0.391863,
#   'Initial atomic coordinate w': 0.278531,
#   "Calculated atomic coordinates u'": 0.693294,
#   "Calculated atomic coordinates v'": 0.389132,
#   "Calculated atomic coordinates w'": 0.27849},
#  {'_id': ObjectId('621756da4774488f72503cff'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.74492,
#   'Initial atomic coordinate v': 0.485609,
#   'Initial atomic coordinate w': 0.348707,
#   "Calculated atomic coordinates u'": 0.763292,
#   "Calculated atomic coordinates v'": 0.491718,
#   "Calculated atomic coordinates w'": 0.348524},
#  {'_id': ObjectId('621756da4774488f72503d00'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.322292,
#   'Initial atomic coordinate v': 0.211065,
#   'Initial atomic coordinate w': 0.331163,
#   "Calculated atomic coordinates u'": 0.318833,
#   "Calculated atomic coordinates v'": 0.197217,
#   "Calculated atomic coordinates w'": 0.331324},
#  {'_id': ObjectId('621756da4774488f72503d01'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.406938,
#   'Initial atomic coordinate v': 0.214257,
#   'Initial atomic coordinate w': 0.401338,
#   "Calculated atomic coordinates u'": 0.411354,
#   "Calculated atomic coordinates v'": 0.203804,
#   "Calculated atomic coordinates w'": 0.401423},
#  {'_id': ObjectId('621756da4774488f72503d02'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.286689,
#   'Initial atomic coordinate v': 0.221323,
#   'Initial atomic coordinate w': 0.462742,
#   "Calculated atomic coordinates u'": 0.280845,
#   "Calculated atomic coordinates v'": 0.207219,
#   "Calculated atomic coordinates w'": 0.462711},
#  {'_id': ObjectId('621756da4774488f72503d03'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.362743,
#   'Initial atomic coordinate v': 0.208688,
#   'Initial atomic coordinate w': 0.532917,
#   "Calculated atomic coordinates u'": 0.363282,
#   "Calculated atomic coordinates v'": 0.196031,
#   "Calculated atomic coordinates w'": 0.532929},
#  {'_id': ObjectId('621756da4774488f72503d04'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.25508,
#   'Initial atomic coordinate v': 0.514391,
#   'Initial atomic coordinate w': 0.515373,
#   "Calculated atomic coordinates u'": 0.242639,
#   "Calculated atomic coordinates v'": 0.512226,
#   "Calculated atomic coordinates w'": 0.515348},
#  {'_id': ObjectId('621756da4774488f72503d05'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.217041,
#   'Initial atomic coordinate v': 0.419085,
#   'Initial atomic coordinate w': 0.585549,
#   "Calculated atomic coordinates u'": 0.204358,
#   "Calculated atomic coordinates v'": 0.411121,
#   "Calculated atomic coordinates w'": 0.585488},
#  {'_id': ObjectId('621756da4774488f72503d06'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.28443,
#   'Initial atomic coordinate v': 0.562111,
#   'Initial atomic coordinate w': 0.646952,
#   "Calculated atomic coordinates u'": 0.27481,
#   "Calculated atomic coordinates v'": 0.563233,
#   "Calculated atomic coordinates w'": 0.646746},
#  {'_id': ObjectId('621756da4774488f72503d07'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.232411,
#   'Initial atomic coordinate v': 0.466278,
#   'Initial atomic coordinate w': 0.717128,
#   "Calculated atomic coordinates u'": 0.218439,
#   "Calculated atomic coordinates v'": 0.460136,
#   "Calculated atomic coordinates w'": 0.716971},
#  {'_id': ObjectId('621756da4774488f72503d08'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.637257,
#   'Initial atomic coordinate v': 0.791312,
#   'Initial atomic coordinate w': 0.699584,
#   "Calculated atomic coordinates u'": 0.641314,
#   "Calculated atomic coordinates v'": 0.807089,
#   "Calculated atomic coordinates w'": 0.699771},
#  {'_id': ObjectId('621756da4774488f72503d09'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.546329,
#   'Initial atomic coordinate v': 0.772379,
#   'Initial atomic coordinate w': 0.769759,
#   "Calculated atomic coordinates u'": 0.541827,
#   "Calculated atomic coordinates v'": 0.784489,
#   "Calculated atomic coordinates w'": 0.769828},
#  {'_id': ObjectId('621756da4774488f72503d0a'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
#   'Initial atomic coordinate u': 0.677708,
#   'Initial atomic coordinate v': 0.788935,
#   'Initial atomic coordinate w': 0.831163,
#   "Calculated atomic coordinates u'": 0.681167,
#   "Calculated atomic coordinates v'": 0.802783,
#   "Calculated atomic coordinates w'": 0.831324},
#  {'_id': ObjectId('621756da4774488f72503d0b'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 2,
# ...
#   "Calculated atomic coordinates u'": 0.122792,
#   "Calculated atomic coordinates v'": 0.274086,
#   "Calculated atomic coordinates w'": 0.050998},
#  {'_id': ObjectId('621756da4774488f72504046'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.145816,
#   'Initial atomic coordinate v': 0.221293,
#   'Initial atomic coordinate w': 0.089208,
#   "Calculated atomic coordinates u'": 0.138865,
#   "Calculated atomic coordinates v'": 0.215329,
#   "Calculated atomic coordinates w'": 0.089298},
#  {'_id': ObjectId('621756da4774488f72504047'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.127612,
#   'Initial atomic coordinate v': 0.293658,
#   'Initial atomic coordinate w': 0.124727,
#   "Calculated atomic coordinates u'": 0.119209,
#   "Calculated atomic coordinates v'": 0.289332,
#   "Calculated atomic coordinates w'": 0.12469},
#  {'_id': ObjectId('621756da4774488f72504048'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.140245,
#   'Initial atomic coordinate v': 0.234433,
#   'Initial atomic coordinate w': 0.162978,
#   "Calculated atomic coordinates u'": 0.130798,
#   "Calculated atomic coordinates v'": 0.227809,
#   "Calculated atomic coordinates w'": 0.162998},
#  {'_id': ObjectId('621756da4774488f72504049'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.204929,
#   'Initial atomic coordinate v': 0.550228,
#   'Initial atomic coordinate w': 0.157514,
#   "Calculated atomic coordinates u'": 0.200566,
#   "Calculated atomic coordinates v'": 0.550105,
#   "Calculated atomic coordinates w'": 0.157617},
#  {'_id': ObjectId('621756da4774488f7250404a'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.164457,
#   'Initial atomic coordinate v': 0.473539,
#   'Initial atomic coordinate w': 0.195765,
#   "Calculated atomic coordinates u'": 0.156814,
#   "Calculated atomic coordinates v'": 0.471262,
#   "Calculated atomic coordinates w'": 0.195847},
#  {'_id': ObjectId('621756da4774488f7250404b'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.217076,
#   'Initial atomic coordinate v': 0.569194,
#   'Initial atomic coordinate w': 0.231284,
#   "Calculated atomic coordinates u'": 0.213413,
#   "Calculated atomic coordinates v'": 0.569382,
#   "Calculated atomic coordinates w'": 0.231275},
#  {'_id': ObjectId('621756da4774488f7250404c'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.173302,
#   'Initial atomic coordinate v': 0.492733,
#   'Initial atomic coordinate w': 0.269536,
#   "Calculated atomic coordinates u'": 0.169523,
#   "Calculated atomic coordinates v'": 0.49184,
#   "Calculated atomic coordinates w'": 0.26961},
#  {'_id': ObjectId('621756da4774488f7250404d'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.448065,
#   'Initial atomic coordinate v': 0.794013,
#   'Initial atomic coordinate w': 0.264071,
#   "Calculated atomic coordinates u'": 0.449231,
#   "Calculated atomic coordinates v'": 0.798812,
#   "Calculated atomic coordinates w'": 0.263991},
#  {'_id': ObjectId('621756da4774488f7250404e'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.373585,
#   'Initial atomic coordinate v': 0.740807,
#   'Initial atomic coordinate w': 0.302323,
#   "Calculated atomic coordinates u'": 0.373226,
#   "Calculated atomic coordinates v'": 0.74489,
#   "Calculated atomic coordinates w'": 0.302345},
#  {'_id': ObjectId('621756da4774488f7250404f'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.467154,
#   'Initial atomic coordinate v': 0.805449,
#   'Initial atomic coordinate w': 0.337842,
#   "Calculated atomic coordinates u'": 0.468006,
#   "Calculated atomic coordinates v'": 0.812379,
#   "Calculated atomic coordinates w'": 0.337955},
#  {'_id': ObjectId('621756da4774488f72504050'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.391824,
#   'Initial atomic coordinate v': 0.755159,
#   'Initial atomic coordinate w': 0.376093,
#   "Calculated atomic coordinates u'": 0.390561,
#   "Calculated atomic coordinates v'": 0.760745,
#   "Calculated atomic coordinates w'": 0.376212},
#  {'_id': ObjectId('621756da4774488f72504051'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.720684,
#   'Initial atomic coordinate v': 0.870888,
#   'Initial atomic coordinate w': 0.370629,
#   "Calculated atomic coordinates u'": 0.726716,
#   "Calculated atomic coordinates v'": 0.879952,
#   "Calculated atomic coordinates w'": 0.370647},
#  {'_id': ObjectId('621756da4774488f72504052'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.654478,
#   'Initial atomic coordinate v': 0.87137,
#   'Initial atomic coordinate w': 0.40888,
#   "Calculated atomic coordinates u'": 0.65835,
#   "Calculated atomic coordinates v'": 0.879991,
#   "Calculated atomic coordinates w'": 0.408953},
#  {'_id': ObjectId('621756da4774488f72504053'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.735879,
#   'Initial atomic coordinate v': 0.868302,
#   'Initial atomic coordinate w': 0.444399,
#   "Calculated atomic coordinates u'": 0.741883,
#   "Calculated atomic coordinates v'": 0.876436,
#   "Calculated atomic coordinates w'": 0.444389},
#  {'_id': ObjectId('621756da4774488f72504054'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.671757,
#   'Initial atomic coordinate v': 0.872732,
#   'Initial atomic coordinate w': 0.48265,
#   "Calculated atomic coordinates u'": 0.676949,
#   "Calculated atomic coordinates v'": 0.881634,
#   "Calculated atomic coordinates w'": 0.482761},
#  {'_id': ObjectId('621756da4774488f72504055'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.868022,
#   'Initial atomic coordinate v': 0.737212,
#   'Initial atomic coordinate w': 0.477186,
#   "Calculated atomic coordinates u'": 0.874466,
#   "Calculated atomic coordinates v'": 0.741481,
#   "Calculated atomic coordinates w'": 0.477178},
#  {'_id': ObjectId('621756da4774488f72504056'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.847674,
#   'Initial atomic coordinate v': 0.791108,
#   'Initial atomic coordinate w': 0.515437,
#   "Calculated atomic coordinates u'": 0.853373,
#   "Calculated atomic coordinates v'": 0.796138,
#   "Calculated atomic coordinates w'": 0.515477},
#  {'_id': ObjectId('621756da4774488f72504057'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.870696,
#   'Initial atomic coordinate v': 0.722072,
#   'Initial atomic coordinate w': 0.550956,
#   "Calculated atomic coordinates u'": 0.877208,
#   "Calculated atomic coordinates v'": 0.725914,
#   "Calculated atomic coordinates w'": 0.550998},
#  {'_id': ObjectId('621756da4774488f72504058'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.854184,
#   'Initial atomic coordinate v': 0.778707,
#   'Initial atomic coordinate w': 0.589208,
#   "Calculated atomic coordinates u'": 0.861135,
#   "Calculated atomic coordinates v'": 0.784671,
#   "Calculated atomic coordinates w'": 0.589298},
#  {'_id': ObjectId('621756da4774488f72504059'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.570887,
#   'Initial atomic coordinate v': 0.218203,
#   'Initial atomic coordinate w': 0.023634,
#   "Calculated atomic coordinates u'": 0.570259,
#   "Calculated atomic coordinates v'": 0.214574,
#   "Calculated atomic coordinates w'": 0.023729},
#  {'_id': ObjectId('621756da4774488f7250405a'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.475259,
#   'Initial atomic coordinate v': 0.165215,
#   'Initial atomic coordinate w': 0.059153,
#   "Calculated atomic coordinates u'": 0.4731,
#   "Calculated atomic coordinates v'": 0.159115,
#   "Calculated atomic coordinates w'": 0.059246},
#  {'_id': ObjectId('621756da4774488f7250405b'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.551935,
#   'Initial atomic coordinate v': 0.205987,
#   'Initial atomic coordinate w': 0.097404,
#   "Calculated atomic coordinates u'": 0.552291,
#   "Calculated atomic coordinates v'": 0.202284,
#   "Calculated atomic coordinates w'": 0.09743},
#  {'_id': ObjectId('621756da4774488f7250405c'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.235646,
#   'Initial atomic coordinate v': 0.139792,
#   'Initial atomic coordinate w': 0.09194,
#   "Calculated atomic coordinates u'": 0.229197,
#   "Calculated atomic coordinates v'": 0.131615,
#   "Calculated atomic coordinates w'": 0.092168},
#  {'_id': ObjectId('621756da4774488f7250405d'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.295096,
#   'Initial atomic coordinate v': 0.127509,
#   'Initial atomic coordinate w': 0.130191,
#   "Calculated atomic coordinates u'": 0.290664,
#   "Calculated atomic coordinates v'": 0.119875,
#   "Calculated atomic coordinates w'": 0.130465},
#  {'_id': ObjectId('621756da4774488f7250405e'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.222442,
#   'Initial atomic coordinate v': 0.145277,
#   'Initial atomic coordinate w': 0.16571,
#   "Calculated atomic coordinates u'": 0.215853,
#   "Calculated atomic coordinates v'": 0.13884,
#   "Calculated atomic coordinates w'": 0.165827},
#  {'_id': ObjectId('621756da4774488f7250405f'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.279316,
#   'Initial atomic coordinate v': 0.129112,
#   'Initial atomic coordinate w': 0.203962,
#   "Calculated atomic coordinates u'": 0.27544,
#   "Calculated atomic coordinates v'": 0.123306,
#   "Calculated atomic coordinates w'": 0.203991},
#  {'_id': ObjectId('621756da4774488f72504060'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.126908,
#   'Initial atomic coordinate v': 0.309934,
#   'Initial atomic coordinate w': 0.198497,
#   "Calculated atomic coordinates u'": 0.11639,
#   "Calculated atomic coordinates v'": 0.304305,
#   "Calculated atomic coordinates w'": 0.19855},
#  {'_id': ObjectId('621756da4774488f72504061'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.135628,
#   'Initial atomic coordinate v': 0.248276,
#   'Initial atomic coordinate w': 0.236749,
#   "Calculated atomic coordinates u'": 0.125888,
#   "Calculated atomic coordinates v'": 0.241451,
#   "Calculated atomic coordinates w'": 0.236835},
#  {'_id': ObjectId('621756da4774488f72504062'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.127194,
#   'Initial atomic coordinate v': 0.326715,
#   'Initial atomic coordinate w': 0.272268,
#   "Calculated atomic coordinates u'": 0.118893,
#   "Calculated atomic coordinates v'": 0.322563,
#   "Calculated atomic coordinates w'": 0.272391},
#  {'_id': ObjectId('621756da4774488f72504063'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.131978,
#   'Initial atomic coordinate v': 0.262788,
#   'Initial atomic coordinate w': 0.310519,
#   "Calculated atomic coordinates u'": 0.1247,
#   "Calculated atomic coordinates v'": 0.257475,
#   "Calculated atomic coordinates w'": 0.310635},
#  {'_id': ObjectId('621756da4774488f72504064'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.229973,
#   'Initial atomic coordinate v': 0.587976,
#   'Initial atomic coordinate w': 0.305055,
#   "Calculated atomic coordinates u'": 0.228853,
#   "Calculated atomic coordinates v'": 0.589941,
#   "Calculated atomic coordinates w'": 0.305015},
#  {'_id': ObjectId('621756da4774488f72504065'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.183013,
#   'Initial atomic coordinate v': 0.511947,
#   'Initial atomic coordinate w': 0.343306,
#   "Calculated atomic coordinates u'": 0.17945,
#   "Calculated atomic coordinates v'": 0.512288,
#   "Calculated atomic coordinates w'": 0.343323},
#  {'_id': ObjectId('621756da4774488f72504066'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.243586,
#   'Initial atomic coordinate v': 0.606525,
#   'Initial atomic coordinate w': 0.378825,
#   "Calculated atomic coordinates u'": 0.24028,
#   "Calculated atomic coordinates v'": 0.609112,
#   "Calculated atomic coordinates w'": 0.378847},
#  {'_id': ObjectId('621756da4774488f72504067'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.193565,
#   'Initial atomic coordinate v': 0.531128,
#   'Initial atomic coordinate w': 0.417077,
#   "Calculated atomic coordinates u'": 0.188609,
#   "Calculated atomic coordinates v'": 0.53124,
#   "Calculated atomic coordinates w'": 0.417057},
#  {'_id': ObjectId('621756da4774488f72504068'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.48633,
#   'Initial atomic coordinate v': 0.816074,
#   'Initial atomic coordinate w': 0.411612,
#   "Calculated atomic coordinates u'": 0.487319,
#   "Calculated atomic coordinates v'": 0.822093,
#   "Calculated atomic coordinates w'": 0.411724},
#  {'_id': ObjectId('621756da4774488f72504069'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.41035,
#   'Initial atomic coordinate v': 0.768835,
#   'Initial atomic coordinate w': 0.449863,
#   "Calculated atomic coordinates u'": 0.410099,
#   "Calculated atomic coordinates v'": 0.77161,
#   "Calculated atomic coordinates w'": 0.450031},
#  {'_id': ObjectId('621756da4774488f7250406a'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.505543,
#   'Initial atomic coordinate v': 0.825862,
#   'Initial atomic coordinate w': 0.485383,
#   "Calculated atomic coordinates u'": 0.507864,
#   "Calculated atomic coordinates v'": 0.830244,
#   "Calculated atomic coordinates w'": 0.485489},
#  {'_id': ObjectId('621756da4774488f7250406b'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.429113,
#   'Initial atomic coordinate v': 0.781797,
#   'Initial atomic coordinate w': 0.523634,
#   "Calculated atomic coordinates u'": 0.429741,
#   "Calculated atomic coordinates v'": 0.785426,
#   "Calculated atomic coordinates w'": 0.523729},
#  {'_id': ObjectId('621756da4774488f7250406c'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.750448,
#   'Initial atomic coordinate v': 0.864739,
#   'Initial atomic coordinate w': 0.51817,
#   "Calculated atomic coordinates u'": 0.757633,
#   "Calculated atomic coordinates v'": 0.87398,
#   "Calculated atomic coordinates w'": 0.518281},
#  {'_id': ObjectId('621756da4774488f7250406d'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.68858,
#   'Initial atomic coordinate v': 0.873107,
#   'Initial atomic coordinate w': 0.556421,
#   "Calculated atomic coordinates u'": 0.693896,
#   "Calculated atomic coordinates v'": 0.881979,
#   "Calculated atomic coordinates w'": 0.556628},
#  {'_id': ObjectId('621756da4774488f7250406e'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.764354,
#   'Initial atomic coordinate v': 0.860208,
#   'Initial atomic coordinate w': 0.59194,
#   "Calculated atomic coordinates u'": 0.770804,
#   "Calculated atomic coordinates v'": 0.868385,
#   "Calculated atomic coordinates w'": 0.592168},
#  {'_id': ObjectId('621756da4774488f7250406f'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.704904,
#   'Initial atomic coordinate v': 0.872491,
#   'Initial atomic coordinate w': 0.630191,
#   "Calculated atomic coordinates u'": 0.709336,
#   "Calculated atomic coordinates v'": 0.880125,
#   "Calculated atomic coordinates w'": 0.630465},
#  {'_id': ObjectId('621756da4774488f72504070'),
#   'Chiral indice n': 5,
#   'Chiral indice m': 4,
#   'Initial atomic coordinate u': 0.872388,
#   'Initial atomic coordinate v': 0.706342,
#   'Initial atomic coordinate w': 0.624727,
#   "Calculated atomic coordinates u'": 0.880792,
#   "Calculated atomic coordinates v'": 0.710668,
#   "Calculated atomic coordinates w'": 0.62469},
#  ...]

# %%
# Insert one or more documents in to the data base
query = [{"name" : "kishore", "profession" : "Data Scientist", "salary" : "60k"},
         {"name" : "yadav", "profession" : "Data Engineer", "salary" : "50k"},
         {"name" : "surya", "profession" : "Full stack developer", "salary" : "80k"},
         {"name" : "srikrishna", "profession" : "Data Analyst", "salary" : "40k"}]
obj.insert(query, "many") # Here i'm inserting the mutiple that's why i put document count is many

# %%
# Filter the documnent with specified conditions
condition = {"name" :{"$in" : ["kishore", "yadav", "srikrishna"]}}
obj.find(condition = condition) # for more documents
# Out:
# [{'_id': ObjectId('621756df4774488f7250666a'),
#   'name': 'kishore',
#   'profession': 'Data Scientist',
#   'salary': '60k'},
#  {'_id': ObjectId('621756df4774488f7250666b'),
#   'name': 'yadav',
#   'profession': 'Data Engineer',
#   'salary': '50k'},
#  {'_id': ObjectId('621756df4774488f7250666d'),
#   'name': 'srikrishna',
#   'profession': 'Data Analyst',
#   'salary': '40k'}]

# %%
obj.find(condition = {'Chiral indice n' : 2})
# Out:
# [{'_id': ObjectId('621756da4774488f72503c89'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.679005,
#   'Initial atomic coordinate v': 0.701318,
#   'Initial atomic coordinate w': 0.017033,
#   "Calculated atomic coordinates u'": 0.721039,
#   "Calculated atomic coordinates v'": 0.730232,
#   "Calculated atomic coordinates w'": 0.017014},
#  {'_id': ObjectId('621756da4774488f72503c8a'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.717298,
#   'Initial atomic coordinate v': 0.642129,
#   'Initial atomic coordinate w': 0.231319,
#   "Calculated atomic coordinates u'": 0.738414,
#   "Calculated atomic coordinates v'": 0.65675,
#   "Calculated atomic coordinates w'": 0.232369},
#  {'_id': ObjectId('621756da4774488f72503c8b'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.489336,
#   'Initial atomic coordinate v': 0.303751,
#   'Initial atomic coordinate w': 0.088462,
#   "Calculated atomic coordinates u'": 0.477676,
#   "Calculated atomic coordinates v'": 0.263221,
#   "Calculated atomic coordinates w'": 0.088712},
#  {'_id': ObjectId('621756da4774488f72503c8c'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.413957,
#   'Initial atomic coordinate v': 0.632996,
#   'Initial atomic coordinate w': 0.040843,
#   "Calculated atomic coordinates u'": 0.408823,
#   "Calculated atomic coordinates v'": 0.657897,
#   "Calculated atomic coordinates w'": 0.039796},
#  {'_id': ObjectId('621756da4774488f72503c8d'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.334292,
#   'Initial atomic coordinate v': 0.543401,
#   'Initial atomic coordinate w': 0.15989,
#   "Calculated atomic coordinates u'": 0.303349,
#   "Calculated atomic coordinates v'": 0.558807,
#   "Calculated atomic coordinates w'": 0.157373},
#  {'_id': ObjectId('621756da4774488f72503c8e'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.510664,
#   'Initial atomic coordinate v': 0.696249,
#   'Initial atomic coordinate w': 0.255128,
#   "Calculated atomic coordinates u'": 0.496977,
#   "Calculated atomic coordinates v'": 0.725608,
#   "Calculated atomic coordinates w'": 0.25597},
#  {'_id': ObjectId('621756da4774488f72503c8f'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.413957,
#   'Initial atomic coordinate v': 0.632996,
#   'Initial atomic coordinate w': 0.374176,
#   "Calculated atomic coordinates u'": 0.390878,
#   "Calculated atomic coordinates v'": 0.657645,
#   "Calculated atomic coordinates w'": 0.374735},
#  {'_id': ObjectId('621756da4774488f72503c90'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.712552,
#   'Initial atomic coordinate v': 0.55479,
#   'Initial atomic coordinate w': 0.112271,
#   "Calculated atomic coordinates u'": 0.750056,
#   "Calculated atomic coordinates v'": 0.561494,
#   "Calculated atomic coordinates w'": 0.114944},
#  {'_id': ObjectId('621756da4774488f72503c91'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.320995,
#   'Initial atomic coordinate v': 0.298682,
#   'Initial atomic coordinate w': 0.1837,
#   "Calculated atomic coordinates u'": 0.281301,
#   "Calculated atomic coordinates v'": 0.261433,
#   "Calculated atomic coordinates w'": 0.182779},
#  {'_id': ObjectId('621756da4774488f72503c92'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.394742,
#   'Initial atomic coordinate v': 0.279367,
#   'Initial atomic coordinate w': 0.302747,
#   "Calculated atomic coordinates u'": 0.35086,
#   "Calculated atomic coordinates v'": 0.2335,
#   "Calculated atomic coordinates w'": 0.302196},
#  {'_id': ObjectId('621756da4774488f72503c93'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.282702,
#   'Initial atomic coordinate v': 0.357871,
#   'Initial atomic coordinate w': 0.397985,
#   "Calculated atomic coordinates u'": 0.229138,
#   "Calculated atomic coordinates v'": 0.328729,
#   "Calculated atomic coordinates w'": 0.398581},
#  {'_id': ObjectId('621756da4774488f72503c94'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.320995,
#   'Initial atomic coordinate v': 0.298682,
#   'Initial atomic coordinate w': 0.517033,
#   "Calculated atomic coordinates u'": 0.278752,
#   "Calculated atomic coordinates v'": 0.269615,
#   "Calculated atomic coordinates w'": 0.51733},
#  {'_id': ObjectId('621756da4774488f72503c95'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.605258,
#   'Initial atomic coordinate v': 0.720633,
#   'Initial atomic coordinate w': 0.469414,
#   "Calculated atomic coordinates u'": 0.613415,
#   "Calculated atomic coordinates v'": 0.760009,
#   "Calculated atomic coordinates w'": 0.469452},
#  {'_id': ObjectId('621756da4774488f72503c96'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.510664,
#   'Initial atomic coordinate v': 0.696249,
#   'Initial atomic coordinate w': 0.588462,
#   "Calculated atomic coordinates u'": 0.521991,
#   "Calculated atomic coordinates v'": 0.736991,
#   "Calculated atomic coordinates w'": 0.588946},
#  {'_id': ObjectId('621756da4774488f72503c97'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.679005,
#   'Initial atomic coordinate v': 0.701318,
#   'Initial atomic coordinate w': 0.6837,
#   "Calculated atomic coordinates u'": 0.718811,
#   "Calculated atomic coordinates v'": 0.738577,
#   "Calculated atomic coordinates w'": 0.68244},
#  {'_id': ObjectId('621756da4774488f72503c98'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.605258,
#   'Initial atomic coordinate v': 0.720633,
#   'Initial atomic coordinate w': 0.802747,
#   "Calculated atomic coordinates u'": 0.649178,
#   "Calculated atomic coordinates v'": 0.766301,
#   "Calculated atomic coordinates w'": 0.80193},
#  {'_id': ObjectId('621756da4774488f72503c99'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.665708,
#   'Initial atomic coordinate v': 0.456599,
#   'Initial atomic coordinate w': 0.326557,
#   "Calculated atomic coordinates u'": 0.680389,
#   "Calculated atomic coordinates v'": 0.444562,
#   "Calculated atomic coordinates w'": 0.327502},
#  {'_id': ObjectId('621756da4774488f72503c9a'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.712552,
#   'Initial atomic coordinate v': 0.55479,
#   'Initial atomic coordinate w': 0.445605,
#   "Calculated atomic coordinates u'": 0.737216,
#   "Calculated atomic coordinates v'": 0.552056,
#   "Calculated atomic coordinates w'": 0.443517},
#  {'_id': ObjectId('621756da4774488f72503c9b'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.586043,
#   'Initial atomic coordinate v': 0.367004,
#   'Initial atomic coordinate w': 0.540843,
#   "Calculated atomic coordinates u'": 0.591153,
#   "Calculated atomic coordinates v'": 0.342069,
#   "Calculated atomic coordinates w'": 0.540172},
#  {'_id': ObjectId('621756da4774488f72503c9c'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.665708,
#   'Initial atomic coordinate v': 0.456599,
#   'Initial atomic coordinate w': 0.65989,
#   "Calculated atomic coordinates u'": 0.697242,
#   "Calculated atomic coordinates v'": 0.441516,
#   "Calculated atomic coordinates w'": 0.657521},
#  {'_id': ObjectId('621756da4774488f72503c9d'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.287448,
#   'Initial atomic coordinate v': 0.44521,
#   'Initial atomic coordinate w': 0.612271,
#   "Calculated atomic coordinates u'": 0.249571,
#   "Calculated atomic coordinates v'": 0.438057,
#   "Calculated atomic coordinates w'": 0.614939},
#  {'_id': ObjectId('621756da4774488f72503c9e'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.282702,
#   'Initial atomic coordinate v': 0.357871,
#   'Initial atomic coordinate w': 0.731319,
#   "Calculated atomic coordinates u'": 0.262916,
#   "Calculated atomic coordinates v'": 0.343512,
#   "Calculated atomic coordinates w'": 0.732213},
#  {'_id': ObjectId('621756da4774488f72503c9f'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.334292,
#   'Initial atomic coordinate v': 0.543401,
#   'Initial atomic coordinate w': 0.826557,
#   "Calculated atomic coordinates u'": 0.320053,
#   "Calculated atomic coordinates v'": 0.555754,
#   "Calculated atomic coordinates w'": 0.827503},
#  {'_id': ObjectId('621756da4774488f72503ca0'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.287448,
#   'Initial atomic coordinate v': 0.44521,
#   'Initial atomic coordinate w': 0.945605,
#   "Calculated atomic coordinates u'": 0.262054,
#   "Calculated atomic coordinates v'": 0.44817,
#   "Calculated atomic coordinates w'": 0.943402},
#  {'_id': ObjectId('621756da4774488f72503ca1'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.717298,
#   'Initial atomic coordinate v': 0.642129,
#   'Initial atomic coordinate w': 0.897985,
#   "Calculated atomic coordinates u'": 0.770521,
#   "Calculated atomic coordinates v'": 0.670869,
#   "Calculated atomic coordinates w'": 0.898389},
#  {'_id': ObjectId('621756da4774488f72503ca2'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.489336,
#   'Initial atomic coordinate v': 0.303751,
#   'Initial atomic coordinate w': 0.755128,
#   "Calculated atomic coordinates u'": 0.50356,
#   "Calculated atomic coordinates v'": 0.27443,
#   "Calculated atomic coordinates w'": 0.75629},
#  {'_id': ObjectId('621756da4774488f72503ca3'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.586043,
#   'Initial atomic coordinate v': 0.367004,
#   'Initial atomic coordinate w': 0.874176,
#   "Calculated atomic coordinates u'": 0.609,
#   "Calculated atomic coordinates v'": 0.342123,
#   "Calculated atomic coordinates w'": 0.875088},
#  {'_id': ObjectId('621756da4774488f72503ca4'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 1,
#   'Initial atomic coordinate u': 0.394742,
#   'Initial atomic coordinate v': 0.279367,
#   'Initial atomic coordinate w': 0.969414,
#   "Calculated atomic coordinates u'": 0.385666,
#   "Calculated atomic coordinates v'": 0.240071,
#   "Calculated atomic coordinates w'": 0.969157}]

# %%
# For first record in database
obj.find("one")
# Out:
# ['_id',
#  'Chiral indice n',
#  'Chiral indice m',
#  'Initial atomic coordinate u',
#  'Initial atomic coordinate v',
#  'Initial atomic coordinate w',
#  "Calculated atomic coordinates u'",
#  "Calculated atomic coordinates v'",
#  "Calculated atomic coordinates w'"]

# %%
# For updating the values

present_data = {'Chiral indice m': 1}
update_data = {"$set" : {'Chiral indice m': 70}}
obj.update("many", present_data, update_data)

# %%
# Finding the values after update

obj.find(condition = {'Chiral indice m': 70})
# Out:
# [{'_id': ObjectId('621756da4774488f72503c89'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.679005,
#   'Initial atomic coordinate v': 0.701318,
#   'Initial atomic coordinate w': 0.017033,
#   "Calculated atomic coordinates u'": 0.721039,
#   "Calculated atomic coordinates v'": 0.730232,
#   "Calculated atomic coordinates w'": 0.017014},
#  {'_id': ObjectId('621756da4774488f72503c8a'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.717298,
#   'Initial atomic coordinate v': 0.642129,
#   'Initial atomic coordinate w': 0.231319,
#   "Calculated atomic coordinates u'": 0.738414,
#   "Calculated atomic coordinates v'": 0.65675,
#   "Calculated atomic coordinates w'": 0.232369},
#  {'_id': ObjectId('621756da4774488f72503c8b'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.489336,
#   'Initial atomic coordinate v': 0.303751,
#   'Initial atomic coordinate w': 0.088462,
#   "Calculated atomic coordinates u'": 0.477676,
#   "Calculated atomic coordinates v'": 0.263221,
#   "Calculated atomic coordinates w'": 0.088712},
#  {'_id': ObjectId('621756da4774488f72503c8c'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.413957,
#   'Initial atomic coordinate v': 0.632996,
#   'Initial atomic coordinate w': 0.040843,
#   "Calculated atomic coordinates u'": 0.408823,
#   "Calculated atomic coordinates v'": 0.657897,
#   "Calculated atomic coordinates w'": 0.039796},
#  {'_id': ObjectId('621756da4774488f72503c8d'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.334292,
#   'Initial atomic coordinate v': 0.543401,
#   'Initial atomic coordinate w': 0.15989,
#   "Calculated atomic coordinates u'": 0.303349,
#   "Calculated atomic coordinates v'": 0.558807,
#   "Calculated atomic coordinates w'": 0.157373},
#  {'_id': ObjectId('621756da4774488f72503c8e'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.510664,
#   'Initial atomic coordinate v': 0.696249,
#   'Initial atomic coordinate w': 0.255128,
#   "Calculated atomic coordinates u'": 0.496977,
#   "Calculated atomic coordinates v'": 0.725608,
#   "Calculated atomic coordinates w'": 0.25597},
#  {'_id': ObjectId('621756da4774488f72503c8f'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.413957,
#   'Initial atomic coordinate v': 0.632996,
#   'Initial atomic coordinate w': 0.374176,
#   "Calculated atomic coordinates u'": 0.390878,
#   "Calculated atomic coordinates v'": 0.657645,
#   "Calculated atomic coordinates w'": 0.374735},
#  {'_id': ObjectId('621756da4774488f72503c90'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.712552,
#   'Initial atomic coordinate v': 0.55479,
#   'Initial atomic coordinate w': 0.112271,
#   "Calculated atomic coordinates u'": 0.750056,
#   "Calculated atomic coordinates v'": 0.561494,
#   "Calculated atomic coordinates w'": 0.114944},
#  {'_id': ObjectId('621756da4774488f72503c91'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.320995,
#   'Initial atomic coordinate v': 0.298682,
#   'Initial atomic coordinate w': 0.1837,
#   "Calculated atomic coordinates u'": 0.281301,
#   "Calculated atomic coordinates v'": 0.261433,
#   "Calculated atomic coordinates w'": 0.182779},
#  {'_id': ObjectId('621756da4774488f72503c92'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.394742,
#   'Initial atomic coordinate v': 0.279367,
#   'Initial atomic coordinate w': 0.302747,
#   "Calculated atomic coordinates u'": 0.35086,
#   "Calculated atomic coordinates v'": 0.2335,
#   "Calculated atomic coordinates w'": 0.302196},
#  {'_id': ObjectId('621756da4774488f72503c93'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.282702,
#   'Initial atomic coordinate v': 0.357871,
#   'Initial atomic coordinate w': 0.397985,
#   "Calculated atomic coordinates u'": 0.229138,
#   "Calculated atomic coordinates v'": 0.328729,
#   "Calculated atomic coordinates w'": 0.398581},
#  {'_id': ObjectId('621756da4774488f72503c94'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.320995,
#   'Initial atomic coordinate v': 0.298682,
#   'Initial atomic coordinate w': 0.517033,
#   "Calculated atomic coordinates u'": 0.278752,
#   "Calculated atomic coordinates v'": 0.269615,
#   "Calculated atomic coordinates w'": 0.51733},
#  {'_id': ObjectId('621756da4774488f72503c95'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.605258,
#   'Initial atomic coordinate v': 0.720633,
#   'Initial atomic coordinate w': 0.469414,
#   "Calculated atomic coordinates u'": 0.613415,
#   "Calculated atomic coordinates v'": 0.760009,
#   "Calculated atomic coordinates w'": 0.469452},
#  {'_id': ObjectId('621756da4774488f72503c96'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.510664,
#   'Initial atomic coordinate v': 0.696249,
#   'Initial atomic coordinate w': 0.588462,
#   "Calculated atomic coordinates u'": 0.521991,
#   "Calculated atomic coordinates v'": 0.736991,
#   "Calculated atomic coordinates w'": 0.588946},
#  {'_id': ObjectId('621756da4774488f72503c97'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.679005,
#   'Initial atomic coordinate v': 0.701318,
#   'Initial atomic coordinate w': 0.6837,
#   "Calculated atomic coordinates u'": 0.718811,
#   "Calculated atomic coordinates v'": 0.738577,
#   "Calculated atomic coordinates w'": 0.68244},
#  {'_id': ObjectId('621756da4774488f72503c98'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.605258,
#   'Initial atomic coordinate v': 0.720633,
#   'Initial atomic coordinate w': 0.802747,
#   "Calculated atomic coordinates u'": 0.649178,
#   "Calculated atomic coordinates v'": 0.766301,
#   "Calculated atomic coordinates w'": 0.80193},
#  {'_id': ObjectId('621756da4774488f72503c99'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.665708,
#   'Initial atomic coordinate v': 0.456599,
#   'Initial atomic coordinate w': 0.326557,
#   "Calculated atomic coordinates u'": 0.680389,
#   "Calculated atomic coordinates v'": 0.444562,
#   "Calculated atomic coordinates w'": 0.327502},
#  {'_id': ObjectId('621756da4774488f72503c9a'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.712552,
#   'Initial atomic coordinate v': 0.55479,
#   'Initial atomic coordinate w': 0.445605,
#   "Calculated atomic coordinates u'": 0.737216,
#   "Calculated atomic coordinates v'": 0.552056,
#   "Calculated atomic coordinates w'": 0.443517},
#  {'_id': ObjectId('621756da4774488f72503c9b'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.586043,
#   'Initial atomic coordinate v': 0.367004,
#   'Initial atomic coordinate w': 0.540843,
#   "Calculated atomic coordinates u'": 0.591153,
#   "Calculated atomic coordinates v'": 0.342069,
#   "Calculated atomic coordinates w'": 0.540172},
#  {'_id': ObjectId('621756da4774488f72503c9c'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.665708,
#   'Initial atomic coordinate v': 0.456599,
#   'Initial atomic coordinate w': 0.65989,
#   "Calculated atomic coordinates u'": 0.697242,
#   "Calculated atomic coordinates v'": 0.441516,
#   "Calculated atomic coordinates w'": 0.657521},
#  {'_id': ObjectId('621756da4774488f72503c9d'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.287448,
#   'Initial atomic coordinate v': 0.44521,
#   'Initial atomic coordinate w': 0.612271,
#   "Calculated atomic coordinates u'": 0.249571,
#   "Calculated atomic coordinates v'": 0.438057,
#   "Calculated atomic coordinates w'": 0.614939},
#  {'_id': ObjectId('621756da4774488f72503c9e'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.282702,
#   'Initial atomic coordinate v': 0.357871,
#   'Initial atomic coordinate w': 0.731319,
#   "Calculated atomic coordinates u'": 0.262916,
#   "Calculated atomic coordinates v'": 0.343512,
#   "Calculated atomic coordinates w'": 0.732213},
#  {'_id': ObjectId('621756da4774488f72503c9f'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.334292,
#   'Initial atomic coordinate v': 0.543401,
#   'Initial atomic coordinate w': 0.826557,
#   "Calculated atomic coordinates u'": 0.320053,
#   "Calculated atomic coordinates v'": 0.555754,
#   "Calculated atomic coordinates w'": 0.827503},
#  {'_id': ObjectId('621756da4774488f72503ca0'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.287448,
#   'Initial atomic coordinate v': 0.44521,
#   'Initial atomic coordinate w': 0.945605,
#   "Calculated atomic coordinates u'": 0.262054,
#   "Calculated atomic coordinates v'": 0.44817,
#   "Calculated atomic coordinates w'": 0.943402},
#  {'_id': ObjectId('621756da4774488f72503ca1'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.717298,
#   'Initial atomic coordinate v': 0.642129,
#   'Initial atomic coordinate w': 0.897985,
#   "Calculated atomic coordinates u'": 0.770521,
#   "Calculated atomic coordinates v'": 0.670869,
#   "Calculated atomic coordinates w'": 0.898389},
#  {'_id': ObjectId('621756da4774488f72503ca2'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.489336,
#   'Initial atomic coordinate v': 0.303751,
#   'Initial atomic coordinate w': 0.755128,
#   "Calculated atomic coordinates u'": 0.50356,
#   "Calculated atomic coordinates v'": 0.27443,
#   "Calculated atomic coordinates w'": 0.75629},
#  {'_id': ObjectId('621756da4774488f72503ca3'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.586043,
#   'Initial atomic coordinate v': 0.367004,
#   'Initial atomic coordinate w': 0.874176,
#   "Calculated atomic coordinates u'": 0.609,
#   "Calculated atomic coordinates v'": 0.342123,
#   "Calculated atomic coordinates w'": 0.875088},
#  {'_id': ObjectId('621756da4774488f72503ca4'),
#   'Chiral indice n': 2,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.394742,
#   'Initial atomic coordinate v': 0.279367,
#   'Initial atomic coordinate w': 0.969414,
#   "Calculated atomic coordinates u'": 0.385666,
#   "Calculated atomic coordinates v'": 0.240071,
#   "Calculated atomic coordinates w'": 0.969157},
#  {'_id': ObjectId('621756da4774488f72503ca5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.591598,
#   'Initial atomic coordinate v': 0.760361,
#   'Initial atomic coordinate w': 0.05909,
#   "Calculated atomic coordinates u'": 0.59912,
#   "Calculated atomic coordinates v'": 0.779052,
#   "Calculated atomic coordinates w'": 0.058651},
#  {'_id': ObjectId('621756da4774488f72503ca6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.24301,
#   'Initial atomic coordinate v': 0.424391,
#   'Initial atomic coordinate w': 0.020628,
#   "Calculated atomic coordinates u'": 0.222068,
#   "Calculated atomic coordinates v'": 0.414703,
#   "Calculated atomic coordinates w'": 0.020882},
#  {'_id': ObjectId('621756da4774488f72503ca7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.348135,
#   'Initial atomic coordinate v': 0.611237,
#   'Initial atomic coordinate w': 0.084731,
#   "Calculated atomic coordinates u'": 0.337437,
#   "Calculated atomic coordinates v'": 0.618899,
#   "Calculated atomic coordinates w'": 0.085676},
#  {'_id': ObjectId('621756da4774488f72503ca8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.300826,
#   'Initial atomic coordinate v': 0.550669,
#   'Initial atomic coordinate w': 0.174474,
#   "Calculated atomic coordinates u'": 0.287789,
#   "Calculated atomic coordinates v'": 0.556575,
#   "Calculated atomic coordinates w'": 0.174486},
#  {'_id': ObjectId('621756da4774488f72503ca9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.732854,
#   'Initial atomic coordinate v': 0.724426,
#   'Initial atomic coordinate w': 0.123192,
#   "Calculated atomic coordinates u'": 0.754953,
#   "Calculated atomic coordinates v'": 0.742501,
#   "Calculated atomic coordinates w'": 0.123074},
#  {'_id': ObjectId('621756da4774488f72503caa'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.696244,
#   'Initial atomic coordinate v': 0.751243,
#   'Initial atomic coordinate w': 0.212936,
#   "Calculated atomic coordinates u'": 0.716721,
#   "Calculated atomic coordinates v'": 0.774579,
#   "Calculated atomic coordinates w'": 0.211887},
#  {'_id': ObjectId('621756da4774488f72503cab'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.764136,
#   'Initial atomic coordinate v': 0.633981,
#   'Initial atomic coordinate w': 0.277038,
#   "Calculated atomic coordinates u'": 0.787393,
#   "Calculated atomic coordinates v'": 0.647285,
#   "Calculated atomic coordinates w'": 0.277407},
#  {'_id': ObjectId('621756da4774488f72503cac'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.755932,
#   'Initial atomic coordinate v': 0.684567,
#   'Initial atomic coordinate w': 0.366782,
#   "Calculated atomic coordinates u'": 0.775712,
#   "Calculated atomic coordinates v'": 0.700545,
#   "Calculated atomic coordinates w'": 0.366505},
#  {'_id': ObjectId('621756da4774488f72503cad'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.699174,
#   'Initial atomic coordinate v': 0.449331,
#   'Initial atomic coordinate w': 0.007807,
#   "Calculated atomic coordinates u'": 0.72086,
#   "Calculated atomic coordinates v'": 0.444281,
#   "Calculated atomic coordinates w'": 0.00759},
#  {'_id': ObjectId('621756da4774488f72503cae'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.734908,
#   'Initial atomic coordinate v': 0.512843,
#   'Initial atomic coordinate w': 0.097551,
#   "Calculated atomic coordinates u'": 0.762097,
#   "Calculated atomic coordinates v'": 0.516121,
#   "Calculated atomic coordinates w'": 0.096337},
#  {'_id': ObjectId('621756da4774488f72503caf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.303756,
#   'Initial atomic coordinate v': 0.248757,
#   'Initial atomic coordinate w': 0.046269,
#   "Calculated atomic coordinates u'": 0.293584,
#   "Calculated atomic coordinates v'": 0.229065,
#   "Calculated atomic coordinates w'": 0.047346},
#  {'_id': ObjectId('621756da4774488f72503cb0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.351772,
#   'Initial atomic coordinate v': 0.236542,
#   'Initial atomic coordinate w': 0.136013,
#   "Calculated atomic coordinates u'": 0.349972,
#   "Calculated atomic coordinates v'": 0.22059,
#   "Calculated atomic coordinates w'": 0.136027},
#  {'_id': ObjectId('621756da4774488f72503cb1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.244068,
#   'Initial atomic coordinate v': 0.315433,
#   'Initial atomic coordinate w': 0.200115,
#   "Calculated atomic coordinates u'": 0.232016,
#   "Calculated atomic coordinates v'": 0.304156,
#   "Calculated atomic coordinates w'": 0.201163},
#  {'_id': ObjectId('621756da4774488f72503cb2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.267146,
#   'Initial atomic coordinate v': 0.275574,
#   'Initial atomic coordinate w': 0.289859,
#   "Calculated atomic coordinates u'": 0.259193,
#   "Calculated atomic coordinates v'": 0.263096,
#   "Calculated atomic coordinates w'": 0.289735},
#  {'_id': ObjectId('621756da4774488f72503cb3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.465969,
#   'Initial atomic coordinate v': 0.709835,
#   'Initial atomic coordinate w': 0.238577,
#   "Calculated atomic coordinates u'": 0.467543,
#   "Calculated atomic coordinates v'": 0.732466,
#   "Calculated atomic coordinates w'": 0.238691},
#  {'_id': ObjectId('621756da4774488f72503cb4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.40427,
#   'Initial atomic coordinate v': 0.665341,
#   'Initial atomic coordinate w': 0.32832,
#   "Calculated atomic coordinates u'": 0.398427,
#   "Calculated atomic coordinates v'": 0.685067,
#   "Calculated atomic coordinates w'": 0.327159},
#  {'_id': ObjectId('621756da4774488f72503cb5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.591598,
#   'Initial atomic coordinate v': 0.760361,
#   'Initial atomic coordinate w': 0.392423,
#   "Calculated atomic coordinates u'": 0.599318,
#   "Calculated atomic coordinates v'": 0.782562,
#   "Calculated atomic coordinates w'": 0.392936},
#  {'_id': ObjectId('621756da4774488f72503cb6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.529645,
#   'Initial atomic coordinate v': 0.742134,
#   'Initial atomic coordinate w': 0.482166,
#   "Calculated atomic coordinates u'": 0.529179,
#   "Calculated atomic coordinates v'": 0.763965,
#   "Calculated atomic coordinates w'": 0.48165},
#  {'_id': ObjectId('621756da4774488f72503cb7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.59573,
#   'Initial atomic coordinate v': 0.334659,
#   'Initial atomic coordinate w': 0.161654,
#   "Calculated atomic coordinates u'": 0.613188,
#   "Calculated atomic coordinates v'": 0.322504,
#   "Calculated atomic coordinates w'": 0.16211},
#  {'_id': ObjectId('621756da4774488f72503cb8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.651865,
#   'Initial atomic coordinate v': 0.388763,
#   'Initial atomic coordinate w': 0.251397,
#   "Calculated atomic coordinates u'": 0.674862,
#   "Calculated atomic coordinates v'": 0.383646,
#   "Calculated atomic coordinates w'": 0.250882},
#  {'_id': ObjectId('621756da4774488f72503cb9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.470355,
#   'Initial atomic coordinate v': 0.257866,
#   'Initial atomic coordinate w': 0.3155,
#   "Calculated atomic coordinates u'": 0.476696,
#   "Calculated atomic coordinates v'": 0.239962,
#   "Calculated atomic coordinates w'": 0.316373},
#  {'_id': ObjectId('621756da4774488f72503cba'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.534031,
#   'Initial atomic coordinate v': 0.290165,
#   'Initial atomic coordinate w': 0.405243,
#   "Calculated atomic coordinates u'": 0.543931,
#   "Calculated atomic coordinates v'": 0.27459,
#   "Calculated atomic coordinates w'": 0.405442},
#  {'_id': ObjectId('621756da4774488f72503cbb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.24301,
#   'Initial atomic coordinate v': 0.424391,
#   'Initial atomic coordinate w': 0.353961,
#   "Calculated atomic coordinates u'": 0.22811,
#   "Calculated atomic coordinates v'": 0.42237,
#   "Calculated atomic coordinates w'": 0.353687},
#  {'_id': ObjectId('621756da4774488f72503cbc'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.235864,
#   'Initial atomic coordinate v': 0.366019,
#   'Initial atomic coordinate w': 0.443705,
#   "Calculated atomic coordinates u'": 0.21931,
#   "Calculated atomic coordinates v'": 0.358527,
#   "Calculated atomic coordinates w'": 0.442351},
#  {'_id': ObjectId('621756da4774488f72503cbd'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.300826,
#   'Initial atomic coordinate v': 0.550669,
#   'Initial atomic coordinate w': 0.507807,
#   "Calculated atomic coordinates u'": 0.27914,
#   "Calculated atomic coordinates v'": 0.555719,
#   "Calculated atomic coordinates w'": 0.50759},
#  {'_id': ObjectId('621756da4774488f72503cbe'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.265092,
#   'Initial atomic coordinate v': 0.487157,
#   'Initial atomic coordinate w': 0.597551,
#   "Calculated atomic coordinates u'": 0.237903,
#   "Calculated atomic coordinates v'": 0.483879,
#   "Calculated atomic coordinates w'": 0.596337},
#  {'_id': ObjectId('621756da4774488f72503cbf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.696244,
#   'Initial atomic coordinate v': 0.751243,
#   'Initial atomic coordinate w': 0.546269,
#   "Calculated atomic coordinates u'": 0.706416,
#   "Calculated atomic coordinates v'": 0.770935,
#   "Calculated atomic coordinates w'": 0.547346},
#  {'_id': ObjectId('621756da4774488f72503cc0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.648228,
#   'Initial atomic coordinate v': 0.763458,
#   'Initial atomic coordinate w': 0.636013,
#   "Calculated atomic coordinates u'": 0.650028,
#   "Calculated atomic coordinates v'": 0.77941,
#   "Calculated atomic coordinates w'": 0.636027},
#  {'_id': ObjectId('621756da4774488f72503cc1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.755932,
#   'Initial atomic coordinate v': 0.684567,
#   'Initial atomic coordinate w': 0.700115,
#   "Calculated atomic coordinates u'": 0.767984,
#   "Calculated atomic coordinates v'": 0.695844,
#   "Calculated atomic coordinates w'": 0.701163},
#  {'_id': ObjectId('621756da4774488f72503cc2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.732854,
#   'Initial atomic coordinate v': 0.724426,
#   'Initial atomic coordinate w': 0.789859,
#   "Calculated atomic coordinates u'": 0.740808,
#   "Calculated atomic coordinates v'": 0.736904,
#   "Calculated atomic coordinates w'": 0.789735},
#  {'_id': ObjectId('621756da4774488f72503cc3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.734908,
#   'Initial atomic coordinate v': 0.512843,
#   'Initial atomic coordinate w': 0.430884,
#   "Calculated atomic coordinates u'": 0.76046,
#   "Calculated atomic coordinates v'": 0.51884,
#   "Calculated atomic coordinates w'": 0.432119},
#  {'_id': ObjectId('621756da4774488f72503cc4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.75699,
#   'Initial atomic coordinate v': 0.575609,
#   'Initial atomic coordinate w': 0.520628,
#   "Calculated atomic coordinates u'": 0.777932,
#   "Calculated atomic coordinates v'": 0.585297,
#   "Calculated atomic coordinates w'": 0.520882},
#  {'_id': ObjectId('621756da4774488f72503cc5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.351772,
#   'Initial atomic coordinate v': 0.236542,
#   'Initial atomic coordinate w': 0.469346,
#   "Calculated atomic coordinates u'": 0.345355,
#   "Calculated atomic coordinates v'": 0.221578,
#   "Calculated atomic coordinates w'": 0.469496},
#  {'_id': ObjectId('621756da4774488f72503cc6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.408402,
#   'Initial atomic coordinate v': 0.239639,
#   'Initial atomic coordinate w': 0.55909,
#   "Calculated atomic coordinates u'": 0.40088,
#   "Calculated atomic coordinates v'": 0.220949,
#   "Calculated atomic coordinates w'": 0.558651},
#  {'_id': ObjectId('621756da4774488f72503cc7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.267146,
#   'Initial atomic coordinate v': 0.275574,
#   'Initial atomic coordinate w': 0.623192,
#   "Calculated atomic coordinates u'": 0.245047,
#   "Calculated atomic coordinates v'": 0.257499,
#   "Calculated atomic coordinates w'": 0.623074},
#  {'_id': ObjectId('621756da4774488f72503cc8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.303756,
#   'Initial atomic coordinate v': 0.248757,
#   'Initial atomic coordinate w': 0.712936,
#   "Calculated atomic coordinates u'": 0.283279,
#   "Calculated atomic coordinates v'": 0.225421,
#   "Calculated atomic coordinates w'": 0.711887},
#  {'_id': ObjectId('621756da4774488f72503cc9'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.40427,
#   'Initial atomic coordinate v': 0.665341,
#   'Initial atomic coordinate w': 0.661654,
#   "Calculated atomic coordinates u'": 0.386812,
#   "Calculated atomic coordinates v'": 0.677496,
#   "Calculated atomic coordinates w'": 0.66211},
#  {'_id': ObjectId('621756da4774488f72503cca'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.348135,
#   'Initial atomic coordinate v': 0.611237,
#   'Initial atomic coordinate w': 0.751397,
#   "Calculated atomic coordinates u'": 0.325138,
#   "Calculated atomic coordinates v'": 0.616354,
#   "Calculated atomic coordinates w'": 0.750882},
#  {'_id': ObjectId('621756da4774488f72503ccb'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.529645,
#   'Initial atomic coordinate v': 0.742134,
#   'Initial atomic coordinate w': 0.8155,
#   "Calculated atomic coordinates u'": 0.523304,
#   "Calculated atomic coordinates v'": 0.760038,
#   "Calculated atomic coordinates w'": 0.816373},
#  {'_id': ObjectId('621756da4774488f72503ccc'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.465969,
#   'Initial atomic coordinate v': 0.709835,
#   'Initial atomic coordinate w': 0.905243,
#   "Calculated atomic coordinates u'": 0.456069,
#   "Calculated atomic coordinates v'": 0.72541,
#   "Calculated atomic coordinates w'": 0.905442},
#  {'_id': ObjectId('621756da4774488f72503ccd'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.764136,
#   'Initial atomic coordinate v': 0.633981,
#   'Initial atomic coordinate w': 0.943705,
#   "Calculated atomic coordinates u'": 0.78069,
#   "Calculated atomic coordinates v'": 0.641473,
#   "Calculated atomic coordinates w'": 0.942351},
#  {'_id': ObjectId('621756da4774488f72503cce'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.651865,
#   'Initial atomic coordinate v': 0.388763,
#   'Initial atomic coordinate w': 0.584731,
#   "Calculated atomic coordinates u'": 0.662563,
#   "Calculated atomic coordinates v'": 0.381101,
#   "Calculated atomic coordinates w'": 0.585676},
#  {'_id': ObjectId('621756da4774488f72503ccf'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.699174,
#   'Initial atomic coordinate v': 0.449331,
#   'Initial atomic coordinate w': 0.674474,
#   "Calculated atomic coordinates u'": 0.712211,
#   "Calculated atomic coordinates v'": 0.443425,
#   "Calculated atomic coordinates w'": 0.674486},
#  {'_id': ObjectId('621756da4774488f72503cd0'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.534031,
#   'Initial atomic coordinate v': 0.290165,
#   'Initial atomic coordinate w': 0.738577,
#   "Calculated atomic coordinates u'": 0.532457,
#   "Calculated atomic coordinates v'": 0.267534,
#   "Calculated atomic coordinates w'": 0.738691},
#  {'_id': ObjectId('621756da4774488f72503cd1'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.59573,
#   'Initial atomic coordinate v': 0.334659,
#   'Initial atomic coordinate w': 0.82832,
#   "Calculated atomic coordinates u'": 0.601573,
#   "Calculated atomic coordinates v'": 0.314933,
#   "Calculated atomic coordinates w'": 0.827159},
#  {'_id': ObjectId('621756da4774488f72503cd2'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.235864,
#   'Initial atomic coordinate v': 0.366019,
#   'Initial atomic coordinate w': 0.777038,
#   "Calculated atomic coordinates u'": 0.212606,
#   "Calculated atomic coordinates v'": 0.352715,
#   "Calculated atomic coordinates w'": 0.777407},
#  {'_id': ObjectId('621756da4774488f72503cd3'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.244068,
#   'Initial atomic coordinate v': 0.315433,
#   'Initial atomic coordinate w': 0.866782,
#   "Calculated atomic coordinates u'": 0.224287,
#   "Calculated atomic coordinates v'": 0.299455,
#   "Calculated atomic coordinates w'": 0.866505},
#  {'_id': ObjectId('621756da4774488f72503cd4'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.265092,
#   'Initial atomic coordinate v': 0.487157,
#   'Initial atomic coordinate w': 0.930884,
#   "Calculated atomic coordinates u'": 0.23954,
#   "Calculated atomic coordinates v'": 0.48116,
#   "Calculated atomic coordinates w'": 0.932119},
#  {'_id': ObjectId('621756da4774488f72503cd5'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.648228,
#   'Initial atomic coordinate v': 0.763458,
#   'Initial atomic coordinate w': 0.969346,
#   "Calculated atomic coordinates u'": 0.654645,
#   "Calculated atomic coordinates v'": 0.778422,
#   "Calculated atomic coordinates w'": 0.969496},
#  {'_id': ObjectId('621756da4774488f72503cd6'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.75699,
#   'Initial atomic coordinate v': 0.575609,
#   'Initial atomic coordinate w': 0.853961,
#   "Calculated atomic coordinates u'": 0.77189,
#   "Calculated atomic coordinates v'": 0.57763,
#   "Calculated atomic coordinates w'": 0.853688},
#  {'_id': ObjectId('621756da4774488f72503cd7'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.408402,
#   'Initial atomic coordinate v': 0.239639,
#   'Initial atomic coordinate w': 0.892423,
#   "Calculated atomic coordinates u'": 0.400682,
#   "Calculated atomic coordinates v'": 0.217438,
#   "Calculated atomic coordinates w'": 0.892936},
#  {'_id': ObjectId('621756da4774488f72503cd8'),
#   'Chiral indice n': 3,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.470355,
#   'Initial atomic coordinate v': 0.257866,
#   'Initial atomic coordinate w': 0.982166,
#   "Calculated atomic coordinates u'": 0.470821,
#   "Calculated atomic coordinates v'": 0.236035,
#   "Calculated atomic coordinates w'": 0.98165},
#  {'_id': ObjectId('621756da4774488f72503d25'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.798626,
#   'Initial atomic coordinate v': 0.65477,
#   'Initial atomic coordinate w': 0.039988,
#   "Calculated atomic coordinates u'": 0.812277,
#   "Calculated atomic coordinates v'": 0.658326,
#   "Calculated atomic coordinates w'": 0.040916},
#  {'_id': ObjectId('621756da4774488f72503d26'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.794352,
#   'Initial atomic coordinate v': 0.691116,
#   'Initial atomic coordinate w': 0.111416,
#   "Calculated atomic coordinates u'": 0.807185,
#   "Calculated atomic coordinates v'": 0.697932,
#   "Calculated atomic coordinates w'": 0.111388},
#  {'_id': ObjectId('621756da4774488f72503d27'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.212784,
#   'Initial atomic coordinate v': 0.427407,
#   'Initial atomic coordinate w': 0.063797,
#   "Calculated atomic coordinates u'": 0.198483,
#   "Calculated atomic coordinates v'": 0.426673,
#   "Calculated atomic coordinates w'": 0.063134},
#  {'_id': ObjectId('621756da4774488f72503d28'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.560308,
#   'Initial atomic coordinate v': 0.783502,
#   'Initial atomic coordinate w': 0.016178,
#   "Calculated atomic coordinates u'": 0.565293,
#   "Calculated atomic coordinates v'": 0.801366,
#   "Calculated atomic coordinates w'": 0.016747},
#  {'_id': ObjectId('621756da4774488f72503d29'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.516033,
#   'Initial atomic coordinate v': 0.766319,
#   'Initial atomic coordinate w': 0.087607,
#   "Calculated atomic coordinates u'": 0.518262,
#   "Calculated atomic coordinates v'": 0.783893,
#   "Calculated atomic coordinates w'": 0.087303},
#  {'_id': ObjectId('621756da4774488f72503d2a'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.681264,
#   'Initial atomic coordinate v': 0.79623,
#   'Initial atomic coordinate w': 0.135226,
#   "Calculated atomic coordinates u'": 0.690505,
#   "Calculated atomic coordinates v'": 0.811887,
#   "Calculated atomic coordinates w'": 0.135963},
#  {'_id': ObjectId('621756da4774488f72503d2b'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.643856,
#   'Initial atomic coordinate v': 0.798626,
#   'Initial atomic coordinate w': 0.206655,
#   "Calculated atomic coordinates u'": 0.653283,
#   "Calculated atomic coordinates v'": 0.815991,
#   "Calculated atomic coordinates w'": 0.206572},
#  {'_id': ObjectId('621756da4774488f72503d2c'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.723194,
#   'Initial atomic coordinate v': 0.439692,
#   'Initial atomic coordinate w': 0.016178,
#   "Calculated atomic coordinates u'": 0.733703,
#   "Calculated atomic coordinates v'": 0.431654,
#   "Calculated atomic coordinates w'": 0.015953},
#  {'_id': ObjectId('621756da4774488f72503d2d'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.356144,
#   'Initial atomic coordinate v': 0.201374,
#   'Initial atomic coordinate w': 0.039988,
#   "Calculated atomic coordinates u'": 0.347059,
#   "Calculated atomic coordinates v'": 0.184129,
#   "Calculated atomic coordinates w'": 0.039263},
#  {'_id': ObjectId('621756da4774488f72503d2e'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.233681,
#   'Initial atomic coordinate v': 0.249714,
#   'Initial atomic coordinate w': 0.087607,
#   "Calculated atomic coordinates u'": 0.220388,
#   "Calculated atomic coordinates v'": 0.238728,
#   "Calculated atomic coordinates w'": 0.087568},
#  {'_id': ObjectId('621756da4774488f72503d2f'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.256813,
#   'Initial atomic coordinate v': 0.228213,
#   'Initial atomic coordinate w': 0.159036,
#   "Calculated atomic coordinates u'": 0.243065,
#   "Calculated atomic coordinates v'": 0.215492,
#   "Calculated atomic coordinates w'": 0.158191},
#  {'_id': ObjectId('621756da4774488f72503d30'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.308884,
#   'Initial atomic coordinate v': 0.603235,
#   'Initial atomic coordinate w': 0.111416,
#   "Calculated atomic coordinates u'": 0.298531,
#   "Calculated atomic coordinates v'": 0.612095,
#   "Calculated atomic coordinates w'": 0.111617},
#  {'_id': ObjectId('621756da4774488f72503d31'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.276806,
#   'Initial atomic coordinate v': 0.560308,
#   'Initial atomic coordinate w': 0.182845,
#   "Calculated atomic coordinates u'": 0.265631,
#   "Calculated atomic coordinates v'": 0.568083,
#   "Calculated atomic coordinates w'": 0.182279},
#  {'_id': ObjectId('621756da4774488f72503d32'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.427407,
#   'Initial atomic coordinate v': 0.714623,
#   'Initial atomic coordinate w': 0.230464,
#   "Calculated atomic coordinates u'": 0.424498,
#   "Calculated atomic coordinates v'": 0.730007,
#   "Calculated atomic coordinates w'": 0.230823},
#  {'_id': ObjectId('621756da4774488f72503d33'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.385034,
#   'Initial atomic coordinate v': 0.681264,
#   'Initial atomic coordinate w': 0.301893,
#   "Calculated atomic coordinates u'": 0.38078,
#   "Calculated atomic coordinates v'": 0.69492,
#   "Calculated atomic coordinates w'": 0.301449},
#  {'_id': ObjectId('621756da4774488f72503d34'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.766319,
#   'Initial atomic coordinate v': 0.750286,
#   'Initial atomic coordinate w': 0.254274,
#   "Calculated atomic coordinates u'": 0.779609,
#   "Calculated atomic coordinates v'": 0.761253,
#   "Calculated atomic coordinates w'": 0.255146},
#  {'_id': ObjectId('621756da4774488f72503d35'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.743187,
#   'Initial atomic coordinate v': 0.771787,
#   'Initial atomic coordinate w': 0.325702,
#   "Calculated atomic coordinates u'": 0.756305,
#   "Calculated atomic coordinates v'": 0.783672,
#   "Calculated atomic coordinates w'": 0.325794},
#  {'_id': ObjectId('621756da4774488f72503d36'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.798626,
#   'Initial atomic coordinate v': 0.65477,
#   'Initial atomic coordinate w': 0.373321,
#   "Calculated atomic coordinates u'": 0.812277,
#   "Calculated atomic coordinates v'": 0.658325,
#   "Calculated atomic coordinates w'": 0.374249},
#  {'_id': ObjectId('621756da4774488f72503d37'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.794352,
#   'Initial atomic coordinate v': 0.691116,
#   'Initial atomic coordinate w': 0.44475,
#   "Calculated atomic coordinates u'": 0.807184,
#   "Calculated atomic coordinates v'": 0.697932,
#   "Calculated atomic coordinates w'": 0.444721},
#  {'_id': ObjectId('621756da4774488f72503d38'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.572593,
#   'Initial atomic coordinate v': 0.285377,
#   'Initial atomic coordinate w': 0.063797,
#   "Calculated atomic coordinates u'": 0.575221,
#   "Calculated atomic coordinates v'": 0.270349,
#   "Calculated atomic coordinates w'": 0.064318},
#  {'_id': ObjectId('621756da4774488f72503d39'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.614966,
#   'Initial atomic coordinate v': 0.318736,
#   'Initial atomic coordinate w': 0.135226,
#   "Calculated atomic coordinates u'": 0.619361,
#   "Calculated atomic coordinates v'": 0.306347,
#   "Calculated atomic coordinates w'": 0.134796},
#  {'_id': ObjectId('621756da4774488f72503d3a'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.439692,
#   'Initial atomic coordinate v': 0.216498,
#   'Initial atomic coordinate w': 0.182845,
#   "Calculated atomic coordinates u'": 0.434731,
#   "Calculated atomic coordinates v'": 0.199076,
#   "Calculated atomic coordinates w'": 0.183122},
#  {'_id': ObjectId('621756da4774488f72503d3b'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.483967,
#   'Initial atomic coordinate v': 0.233681,
#   'Initial atomic coordinate w': 0.254274,
#   "Calculated atomic coordinates u'": 0.48176,
#   "Calculated atomic coordinates v'": 0.214825,
#   "Calculated atomic coordinates w'": 0.253602},
#  {'_id': ObjectId('621756da4774488f72503d3c'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.201374,
#   'Initial atomic coordinate v': 0.34523,
#   'Initial atomic coordinate w': 0.206655,
#   "Calculated atomic coordinates u'": 0.18762,
#   "Calculated atomic coordinates v'": 0.340879,
#   "Calculated atomic coordinates w'": 0.20662},
#  {'_id': ObjectId('621756da4774488f72503d3d'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.205648,
#   'Initial atomic coordinate v': 0.308884,
#   'Initial atomic coordinate w': 0.278083,
#   "Calculated atomic coordinates u'": 0.194081,
#   "Calculated atomic coordinates v'": 0.302779,
#   "Calculated atomic coordinates w'": 0.277111},
#  {'_id': ObjectId('621756da4774488f72503d3e'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.228213,
#   'Initial atomic coordinate v': 0.471401,
#   'Initial atomic coordinate w': 0.325702,
#   "Calculated atomic coordinates u'": 0.216119,
#   "Calculated atomic coordinates v'": 0.472308,
#   "Calculated atomic coordinates w'": 0.325774},
#  {'_id': ObjectId('621756da4774488f72503d3f'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.212784,
#   'Initial atomic coordinate v': 0.427407,
#   'Initial atomic coordinate w': 0.397131,
#   "Calculated atomic coordinates u'": 0.198483,
#   "Calculated atomic coordinates v'": 0.426673,
#   "Calculated atomic coordinates w'": 0.396467},
#  {'_id': ObjectId('621756da4774488f72503d40'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.560308,
#   'Initial atomic coordinate v': 0.783502,
#   'Initial atomic coordinate w': 0.349512,
#   "Calculated atomic coordinates u'": 0.565293,
#   "Calculated atomic coordinates v'": 0.801366,
#   "Calculated atomic coordinates w'": 0.350081},
#  {'_id': ObjectId('621756da4774488f72503d41'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.516033,
#   'Initial atomic coordinate v': 0.766319,
#   'Initial atomic coordinate w': 0.42094,
#   "Calculated atomic coordinates u'": 0.518261,
#   "Calculated atomic coordinates v'": 0.783893,
#   "Calculated atomic coordinates w'": 0.420636},
#  {'_id': ObjectId('621756da4774488f72503d42'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.681264,
#   'Initial atomic coordinate v': 0.79623,
#   'Initial atomic coordinate w': 0.468559,
#   "Calculated atomic coordinates u'": 0.690505,
#   "Calculated atomic coordinates v'": 0.811887,
#   "Calculated atomic coordinates w'": 0.469296},
#  {'_id': ObjectId('621756da4774488f72503d43'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.643856,
#   'Initial atomic coordinate v': 0.798626,
#   'Initial atomic coordinate w': 0.539988,
#   "Calculated atomic coordinates u'": 0.653282,
#   "Calculated atomic coordinates v'": 0.815991,
#   "Calculated atomic coordinates w'": 0.539906},
#  {'_id': ObjectId('621756da4774488f72503d44'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.771787,
#   'Initial atomic coordinate v': 0.528599,
#   'Initial atomic coordinate w': 0.159036,
#   "Calculated atomic coordinates u'": 0.784977,
#   "Calculated atomic coordinates v'": 0.528527,
#   "Calculated atomic coordinates w'": 0.159828},
#  {'_id': ObjectId('621756da4774488f72503d45'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.787216,
#   'Initial atomic coordinate v': 0.572593,
#   'Initial atomic coordinate w': 0.230464,
#   "Calculated atomic coordinates u'": 0.80108,
#   "Calculated atomic coordinates v'": 0.573294,
#   "Calculated atomic coordinates w'": 0.230421},
#  {'_id': ObjectId('621756da4774488f72503d46'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.691116,
#   'Initial atomic coordinate v': 0.396765,
#   'Initial atomic coordinate w': 0.278083,
#   "Calculated atomic coordinates u'": 0.70063,
#   "Calculated atomic coordinates v'": 0.387602,
#   "Calculated atomic coordinates w'": 0.278662},
#  {'_id': ObjectId('621756da4774488f72503d47'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.723194,
#   'Initial atomic coordinate v': 0.439692,
#   'Initial atomic coordinate w': 0.349512,
#   "Calculated atomic coordinates u'": 0.733703,
#   "Calculated atomic coordinates v'": 0.431653,
#   "Calculated atomic coordinates w'": 0.349287},
#  {'_id': ObjectId('621756da4774488f72503d48'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.318736,
#   'Initial atomic coordinate v': 0.20377,
#   'Initial atomic coordinate w': 0.301893,
#   "Calculated atomic coordinates u'": 0.309563,
#   "Calculated atomic coordinates v'": 0.187916,
#   "Calculated atomic coordinates w'": 0.301969},
#  {'_id': ObjectId('621756da4774488f72503d49'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.356144,
#   'Initial atomic coordinate v': 0.201374,
#   'Initial atomic coordinate w': 0.373321,
#   "Calculated atomic coordinates u'": 0.347059,
#   "Calculated atomic coordinates v'": 0.184129,
#   "Calculated atomic coordinates w'": 0.372596},
#  {'_id': ObjectId('621756da4774488f72503d4a'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.233681,
#   'Initial atomic coordinate v': 0.249714,
#   'Initial atomic coordinate w': 0.42094,
#   "Calculated atomic coordinates u'": 0.220388,
#   "Calculated atomic coordinates v'": 0.238728,
#   "Calculated atomic coordinates w'": 0.420901},
#  {'_id': ObjectId('621756da4774488f72503d4b'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.256813,
#   'Initial atomic coordinate v': 0.228213,
#   'Initial atomic coordinate w': 0.492369,
#   "Calculated atomic coordinates u'": 0.243066,
#   "Calculated atomic coordinates v'": 0.215492,
#   "Calculated atomic coordinates w'": 0.491525},
#  {'_id': ObjectId('621756da4774488f72503d4c'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.308884,
#   'Initial atomic coordinate v': 0.603235,
#   'Initial atomic coordinate w': 0.44475,
#   "Calculated atomic coordinates u'": 0.298531,
#   "Calculated atomic coordinates v'": 0.612095,
#   "Calculated atomic coordinates w'": 0.444951},
#  {'_id': ObjectId('621756da4774488f72503d4d'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.276806,
#   'Initial atomic coordinate v': 0.560308,
#   'Initial atomic coordinate w': 0.516178,
#   "Calculated atomic coordinates u'": 0.265631,
#   "Calculated atomic coordinates v'": 0.568083,
#   "Calculated atomic coordinates w'": 0.515612},
#  {'_id': ObjectId('621756da4774488f72503d4e'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.427407,
#   'Initial atomic coordinate v': 0.714623,
#   'Initial atomic coordinate w': 0.563797,
#   "Calculated atomic coordinates u'": 0.424498,
#   "Calculated atomic coordinates v'": 0.730007,
#   "Calculated atomic coordinates w'": 0.564156},
#  {'_id': ObjectId('621756da4774488f72503d4f'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.385034,
#   'Initial atomic coordinate v': 0.681264,
#   'Initial atomic coordinate w': 0.635226,
#   "Calculated atomic coordinates u'": 0.38078,
#   "Calculated atomic coordinates v'": 0.69492,
#   "Calculated atomic coordinates w'": 0.634783},
#  {'_id': ObjectId('621756da4774488f72503d50'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.766319,
#   'Initial atomic coordinate v': 0.750286,
#   'Initial atomic coordinate w': 0.587607,
#   "Calculated atomic coordinates u'": 0.779608,
#   "Calculated atomic coordinates v'": 0.761253,
#   "Calculated atomic coordinates w'": 0.588479},
#  {'_id': ObjectId('621756da4774488f72503d51'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.743187,
#   'Initial atomic coordinate v': 0.771787,
#   'Initial atomic coordinate w': 0.659036,
#   "Calculated atomic coordinates u'": 0.756305,
#   "Calculated atomic coordinates v'": 0.783671,
#   "Calculated atomic coordinates w'": 0.659127},
#  {'_id': ObjectId('621756da4774488f72503d52'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.798626,
#   'Initial atomic coordinate v': 0.65477,
#   'Initial atomic coordinate w': 0.706655,
#   "Calculated atomic coordinates u'": 0.812277,
#   "Calculated atomic coordinates v'": 0.658326,
#   "Calculated atomic coordinates w'": 0.707583},
#  {'_id': ObjectId('621756da4774488f72503d53'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.794352,
#   'Initial atomic coordinate v': 0.691116,
#   'Initial atomic coordinate w': 0.778083,
#   "Calculated atomic coordinates u'": 0.807185,
#   "Calculated atomic coordinates v'": 0.697932,
#   "Calculated atomic coordinates w'": 0.778054},
#  {'_id': ObjectId('621756da4774488f72503d54'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.572593,
#   'Initial atomic coordinate v': 0.285377,
#   'Initial atomic coordinate w': 0.397131,
#   "Calculated atomic coordinates u'": 0.575221,
#   "Calculated atomic coordinates v'": 0.270348,
#   "Calculated atomic coordinates w'": 0.397652},
#  {'_id': ObjectId('621756da4774488f72503d55'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.614966,
#   'Initial atomic coordinate v': 0.318736,
#   'Initial atomic coordinate w': 0.468559,
#   "Calculated atomic coordinates u'": 0.619361,
#   "Calculated atomic coordinates v'": 0.306346,
#   "Calculated atomic coordinates w'": 0.468129},
#  {'_id': ObjectId('621756da4774488f72503d56'),
#   'Chiral indice n': 4,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.439692,
#   'Initial atomic coordinate v': 0.216498,
#   'Initial atomic coordinate w': 0.516178,
#   "Calculated atomic coordinates u'": 0.434732,
#   "Calculated atomic coordinates v'": 0.199076,
# ...
#   "Calculated atomic coordinates v'": 0.328922,
#   "Calculated atomic coordinates w'": 0.83564},
#  {'_id': ObjectId('621756da4774488f72504ddb'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.727622,
#   'Initial atomic coordinate v': 0.345116,
#   'Initial atomic coordinate w': 0.874693,
#   "Calculated atomic coordinates u'": 0.73306,
#   "Calculated atomic coordinates v'": 0.342908,
#   "Calculated atomic coordinates w'": 0.874498},
#  {'_id': ObjectId('621756da4774488f72504ddc'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.44566,
#   'Initial atomic coordinate v': 0.142919,
#   'Initial atomic coordinate w': 0.842729,
#   "Calculated atomic coordinates u'": 0.445638,
#   "Calculated atomic coordinates v'": 0.137434,
#   "Calculated atomic coordinates w'": 0.842489},
#  {'_id': ObjectId('621756da4774488f72504ddd'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.4621,
#   'Initial atomic coordinate v': 0.14942,
#   'Initial atomic coordinate w': 0.881542,
#   "Calculated atomic coordinates u'": 0.462522,
#   "Calculated atomic coordinates v'": 0.143661,
#   "Calculated atomic coordinates w'": 0.881341},
#  {'_id': ObjectId('621756da4774488f72504dde'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.335075,
#   'Initial atomic coordinate v': 0.116447,
#   'Initial atomic coordinate w': 0.904373,
#   "Calculated atomic coordinates u'": 0.333185,
#   "Calculated atomic coordinates v'": 0.110526,
#   "Calculated atomic coordinates w'": 0.904252},
#  {'_id': ObjectId('621756da4774488f72504ddf'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.350185,
#   'Initial atomic coordinate v': 0.118136,
#   'Initial atomic coordinate w': 0.943186,
#   "Calculated atomic coordinates u'": 0.347417,
#   "Calculated atomic coordinates v'": 0.111178,
#   "Calculated atomic coordinates w'": 0.94317},
#  {'_id': ObjectId('621756da4774488f72504de0'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.145013,
#   'Initial atomic coordinate v': 0.193883,
#   'Initial atomic coordinate w': 0.911222,
#   "Calculated atomic coordinates u'": 0.13888,
#   "Calculated atomic coordinates v'": 0.188161,
#   "Calculated atomic coordinates w'": 0.911137},
#  {'_id': ObjectId('621756da4774488f72504de1'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.151732,
#   'Initial atomic coordinate v': 0.184135,
#   'Initial atomic coordinate w': 0.950035,
#   "Calculated atomic coordinates u'": 0.144916,
#   "Calculated atomic coordinates v'": 0.177985,
#   "Calculated atomic coordinates w'": 0.950038},
#  {'_id': ObjectId('621756da4774488f72504de2'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.116931,
#   'Initial atomic coordinate v': 0.276852,
#   'Initial atomic coordinate w': 0.972866,
#   "Calculated atomic coordinates u'": 0.1101,
#   "Calculated atomic coordinates v'": 0.272904,
#   "Calculated atomic coordinates w'": 0.972987},
#  {'_id': ObjectId('621756da4774488f72504de3'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.19057,
#   'Initial atomic coordinate v': 0.543389,
#   'Initial atomic coordinate w': 0.979716,
#   "Calculated atomic coordinates u'": 0.184601,
#   "Calculated atomic coordinates v'": 0.543809,
#   "Calculated atomic coordinates w'": 0.97988},
#  {'_id': ObjectId('621756da4774488f72504de4'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.87291,
#   'Initial atomic coordinate v': 0.604241,
#   'Initial atomic coordinate w': 0.829031,
#   "Calculated atomic coordinates u'": 0.881496,
#   "Calculated atomic coordinates v'": 0.607957,
#   "Calculated atomic coordinates w'": 0.828762},
#  {'_id': ObjectId('621756da4774488f72504de5'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.876649,
#   'Initial atomic coordinate v': 0.620081,
#   'Initial atomic coordinate w': 0.867843,
#   "Calculated atomic coordinates u'": 0.885369,
#   "Calculated atomic coordinates v'": 0.623543,
#   "Calculated atomic coordinates w'": 0.867627},
#  {'_id': ObjectId('621756da4774488f72504de6'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.827949,
#   'Initial atomic coordinate v': 0.48964,
#   'Initial atomic coordinate w': 0.890674,
#   "Calculated atomic coordinates u'": 0.834356,
#   "Calculated atomic coordinates v'": 0.490183,
#   "Calculated atomic coordinates w'": 0.890556},
#  {'_id': ObjectId('621756da4774488f72504de7'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.836306,
#   'Initial atomic coordinate v': 0.506199,
#   'Initial atomic coordinate w': 0.929487,
#   "Calculated atomic coordinates u'": 0.84213,
#   "Calculated atomic coordinates v'": 0.506731,
#   "Calculated atomic coordinates w'": 0.929491},
#  {'_id': ObjectId('621756da4774488f72504de8'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.609544,
#   'Initial atomic coordinate v': 0.23531,
#   'Initial atomic coordinate w': 0.897524,
#   "Calculated atomic coordinates u'": 0.612608,
#   "Calculated atomic coordinates v'": 0.230966,
#   "Calculated atomic coordinates w'": 0.897405},
#  {'_id': ObjectId('621756da4774488f72504de9'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.625313,
#   'Initial atomic coordinate v': 0.247572,
#   'Initial atomic coordinate w': 0.936337,
#   "Calculated atomic coordinates u'": 0.628171,
#   "Calculated atomic coordinates v'": 0.242705,
#   "Calculated atomic coordinates w'": 0.936282},
#  {'_id': ObjectId('621756da4774488f72504dea'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.495159,
#   'Initial atomic coordinate v': 0.164356,
#   'Initial atomic coordinate w': 0.959168,
#   "Calculated atomic coordinates u'": 0.494786,
#   "Calculated atomic coordinates v'": 0.158759,
#   "Calculated atomic coordinates w'": 0.959219},
#  {'_id': ObjectId('621756da4774488f72504deb'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.511717,
#   'Initial atomic coordinate v': 0.172763,
#   'Initial atomic coordinate w': 0.99798,
#   "Calculated atomic coordinates u'": 0.511294,
#   "Calculated atomic coordinates v'": 0.166397,
#   "Calculated atomic coordinates w'": 0.998139},
#  {'_id': ObjectId('621756da4774488f72504dec'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.239344,
#   'Initial atomic coordinate v': 0.12452,
#   'Initial atomic coordinate w': 0.966017,
#   "Calculated atomic coordinates u'": 0.233869,
#   "Calculated atomic coordinates v'": 0.11705,
#   "Calculated atomic coordinates w'": 0.966125},
#  {'_id': ObjectId('621756da4774488f72504ded'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.882029,
#   'Initial atomic coordinate v': 0.651064,
#   'Initial atomic coordinate w': 0.945469,
#   "Calculated atomic coordinates u'": 0.889382,
#   "Calculated atomic coordinates v'": 0.654078,
#   "Calculated atomic coordinates w'": 0.945547},
#  {'_id': ObjectId('621756da4774488f72504dee'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.88366,
#   'Initial atomic coordinate v': 0.66615,
#   'Initial atomic coordinate w': 0.984282,
#   "Calculated atomic coordinates u'": 0.889559,
#   "Calculated atomic coordinates v'": 0.668092,
#   "Calculated atomic coordinates w'": 0.984462},
#  {'_id': ObjectId('621756da4774488f72504def'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.753451,
#   'Initial atomic coordinate v': 0.375972,
#   'Initial atomic coordinate w': 0.952318,
#   "Calculated atomic coordinates u'": 0.758558,
#   "Calculated atomic coordinates v'": 0.373343,
#   "Calculated atomic coordinates w'": 0.952418},
#  {'_id': ObjectId('621756da4774488f72504df0'),
#   'Chiral indice n': 8,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.765673,
#   'Initial atomic coordinate v': 0.391758,
#   'Initial atomic coordinate w': 0.991131,
#   "Calculated atomic coordinates u'": 0.770068,
#   "Calculated atomic coordinates v'": 0.388623,
#   "Calculated atomic coordinates w'": 0.991301},
#  {'_id': ObjectId('621756da4774488f725053b9'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.762983,
#   'Initial atomic coordinate v': 0.890987,
#   'Initial atomic coordinate w': 0.000411,
#   "Calculated atomic coordinates u'": 0.766428,
#   "Calculated atomic coordinates v'": 0.897776,
#   "Calculated atomic coordinates w'": 0.000354},
#  {'_id': ObjectId('621756da4774488f725053ba'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.891159,
#   'Initial atomic coordinate v': 0.762318,
#   'Initial atomic coordinate w': 0.005906,
#   "Calculated atomic coordinates u'": 0.895939,
#   "Calculated atomic coordinates v'": 0.765263,
#   "Calculated atomic coordinates w'": 0.005862},
#  {'_id': ObjectId('621756da4774488f725053bb'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.646064,
#   'Initial atomic coordinate v': 0.89429,
#   'Initial atomic coordinate w': 0.015063,
#   "Calculated atomic coordinates u'": 0.646953,
#   "Calculated atomic coordinates v'": 0.900126,
#   "Calculated atomic coordinates w'": 0.015075},
#  {'_id': ObjectId('621756da4774488f725053bc'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.633173,
#   'Initial atomic coordinate v': 0.89202,
#   'Initial atomic coordinate w': 0.049862,
#   "Calculated atomic coordinates u'": 0.633355,
#   "Calculated atomic coordinates v'": 0.896101,
#   "Calculated atomic coordinates w'": 0.049822},
#  {'_id': ObjectId('621756da4774488f725053bd'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.842,
#   'Initial atomic coordinate v': 0.84844,
#   'Initial atomic coordinate w': 0.020558,
#   "Calculated atomic coordinates u'": 0.8458,
#   "Calculated atomic coordinates v'": 0.852965,
#   "Calculated atomic coordinates w'": 0.020519},
#  {'_id': ObjectId('621756da4774488f725053be'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.834724,
#   'Initial atomic coordinate v': 0.854919,
#   'Initial atomic coordinate w': 0.055356,
#   "Calculated atomic coordinates u'": 0.837066,
#   "Calculated atomic coordinates v'": 0.857681,
#   "Calculated atomic coordinates w'": 0.055331},
#  {'_id': ObjectId('621756da4774488f725053bf'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.88491,
#   'Initial atomic coordinate v': 0.782406,
#   'Initial atomic coordinate w': 0.075503,
#   "Calculated atomic coordinates u'": 0.888805,
#   "Calculated atomic coordinates v'": 0.784962,
#   "Calculated atomic coordinates w'": 0.075671},
#  {'_id': ObjectId('621756da4774488f725053c0'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.881096,
#   'Initial atomic coordinate v': 0.791951,
#   'Initial atomic coordinate w': 0.110301,
#   "Calculated atomic coordinates u'": 0.883599,
#   "Calculated atomic coordinates v'": 0.793796,
#   "Calculated atomic coordinates w'": 0.110453},
#  {'_id': ObjectId('621756da4774488f725053c1'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.178807,
#   'Initial atomic coordinate v': 0.543937,
#   'Initial atomic coordinate w': 0.004074,
#   "Calculated atomic coordinates u'": 0.172357,
#   "Calculated atomic coordinates v'": 0.543551,
#   "Calculated atomic coordinates w'": 0.004062},
#  {'_id': ObjectId('621756da4774488f725053c2'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.170846,
#   'Initial atomic coordinate v': 0.530234,
#   'Initial atomic coordinate w': 0.038873,
#   "Calculated atomic coordinates u'": 0.163269,
#   "Calculated atomic coordinates v'": 0.528193,
#   "Calculated atomic coordinates w'": 0.038712},
#  {'_id': ObjectId('621756da4774488f725053c3'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.389505,
#   'Initial atomic coordinate v': 0.776492,
#   'Initial atomic coordinate w': 0.009569,
#   "Calculated atomic coordinates u'": 0.385827,
#   "Calculated atomic coordinates v'": 0.77921,
#   "Calculated atomic coordinates w'": 0.009598},
#  {'_id': ObjectId('621756da4774488f725053c4'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.376349,
#   'Initial atomic coordinate v': 0.766414,
#   'Initial atomic coordinate w': 0.044367,
#   "Calculated atomic coordinates u'": 0.372008,
#   "Calculated atomic coordinates v'": 0.767335,
#   "Calculated atomic coordinates w'": 0.044297},
#  {'_id': ObjectId('621756da4774488f725053c5'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.498148,
#   'Initial atomic coordinate v': 0.844335,
#   'Initial atomic coordinate w': 0.064514,
#   "Calculated atomic coordinates u'": 0.495834,
#   "Calculated atomic coordinates v'": 0.844863,
#   "Calculated atomic coordinates w'": 0.064526},
#  {'_id': ObjectId('621756da4774488f725053c6'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.484388,
#   'Initial atomic coordinate v': 0.837194,
#   'Initial atomic coordinate w': 0.099312,
#   "Calculated atomic coordinates u'": 0.480215,
#   "Calculated atomic coordinates v'": 0.836461,
#   "Calculated atomic coordinates w'": 0.099277},
#  {'_id': ObjectId('621756da4774488f725053c7'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.741684,
#   'Initial atomic coordinate v': 0.895432,
#   'Initial atomic coordinate w': 0.070008,
#   "Calculated atomic coordinates u'": 0.743257,
#   "Calculated atomic coordinates v'": 0.899421,
#   "Calculated atomic coordinates w'": 0.070095},
#  {'_id': ObjectId('621756da4774488f725053c8'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.730596,
#   'Initial atomic coordinate v': 0.896949,
#   'Initial atomic coordinate w': 0.104807,
#   "Calculated atomic coordinates u'": 0.730537,
#   "Calculated atomic coordinates v'": 0.899593,
#   "Calculated atomic coordinates w'": 0.104861},
#  {'_id': ObjectId('621756da4774488f725053c9'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.818985,
#   'Initial atomic coordinate v': 0.866602,
#   'Initial atomic coordinate w': 0.124953,
#   "Calculated atomic coordinates u'": 0.82012,
#   "Calculated atomic coordinates v'": 0.869566,
#   "Calculated atomic coordinates w'": 0.125177},
#  {'_id': ObjectId('621756da4774488f725053ca'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.810541,
#   'Initial atomic coordinate v': 0.871791,
#   'Initial atomic coordinate w': 0.159752,
#   "Calculated atomic coordinates u'": 0.810988,
#   "Calculated atomic coordinates v'": 0.874089,
#   "Calculated atomic coordinates w'": 0.159904},
#  {'_id': ObjectId('621756da4774488f725053cb'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.898582,
#   'Initial atomic coordinate v': 0.706854,
#   'Initial atomic coordinate w': 0.165246,
#   "Calculated atomic coordinates u'": 0.90156,
#   "Calculated atomic coordinates v'": 0.707691,
#   "Calculated atomic coordinates w'": 0.16533},
#  {'_id': ObjectId('621756da4774488f725053cc'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.198274,
#   'Initial atomic coordinate v': 0.123462,
#   'Initial atomic coordinate w': 0.027884,
#   "Calculated atomic coordinates u'": 0.193243,
#   "Calculated atomic coordinates v'": 0.117057,
#   "Calculated atomic coordinates w'": 0.027711},
#  {'_id': ObjectId('621756da4774488f725053cd'),
#   'Chiral indice n': 9,
#   'Chiral indice m': 70,
#   'Initial atomic coordinate u': 0.101957,
#   'Initial atomic coordinate v': 0.281505,
#   'Initial atomic coordinate w': 0.033378,
#   "Calculated atomic coordinates u'": 0.093756,
#   "Calculated atomic coordinates v'": 0.276291,
#   "Calculated atomic coordinates w'": 0.033106},
#  ...]

# %%
# Delete all documents from the collection

obj.delete_entire_collection()

# %%
# Delete the specified collection from the database

obj.drop_collection("coll")

# %%
# Remove the connection between the python and mongodb

obj.close()

# %%
# Description of Class

print(obj)
# Out:
# It is mongoBD class and performs different nosql operations

# %%
logging.shutdown()
